# %%
import lxml
from lxml import etree
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import os, os.path
from lxml import etree as ET

# %%
VLO41_diffusion_Keil = pd.read_csv('/Users/vlachou/Desktop/ENC/MEMOIRE/Eutyches/comparative_mss_analysis/diffusion_csv/diffusion_VLO41_annotations_Keil.csv',encoding='utf-8')
Bamberg_diffusion_Keil = pd.read_csv('/Users/vlachou/Desktop/ENC/MEMOIRE/Eutyches/comparative_mss_analysis/diffusion_csv/diffusion_Bamberg_annotations_Keil.csv',encoding='utf-8')
Lat14087_diffusion_Keil = pd.read_csv('/Users/vlachou/Desktop/ENC/MEMOIRE/Eutyches/comparative_mss_analysis/diffusion_csv/diffusion_Lat14087_annotations_Keil.csv',encoding='utf-8')
Lat7499_diffusion_Keil = pd.read_csv('/Users/vlachou/Desktop/ENC/MEMOIRE/Eutyches/comparative_mss_analysis/diffusion_csv/diffusion_Lat7499_annotations_Keil.csv',encoding='utf-8')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define custom color palette
colors = ['#9619F3', '#DE2772', '#21F8EE', '#2E3FEF'] #'#F175AF'

# Concatenate the dataframes horizontally
merged_df = pd.concat([VLO41_diffusion_Keil['gloss'].rename('gloss_id_VLO41'), 
                       VLO41_diffusion_Keil['marginal_note_id'].rename('marginal_note_id_VLO41'),
                       Bamberg_diffusion_Keil['gloss'].rename('gloss_id_Bamberg'), 
                       Bamberg_diffusion_Keil['marginal_note_id'].rename('marginal_note_id_Bamberg'),
                       Lat14087_diffusion_Keil['gloss'].rename('gloss_id_Lat14087'),
                       Lat7499_diffusion_Keil['gloss'].rename('gloss_id_Lat7499'), 
                       Lat7499_diffusion_Keil['marginal_note_id'].rename('marginal_note_id_Lat7499')], axis=1, sort=False)

merged_df['page'] = Bamberg_diffusion_Keil['page']

# Calculate the total annotations per page by summing the values
merged_df['total_annotations_VLO41'] = merged_df['gloss_id_VLO41'] + merged_df['marginal_note_id_VLO41']
merged_df['total_annotations_Bamberg'] = merged_df['gloss_id_Bamberg'] + merged_df['marginal_note_id_Bamberg']
merged_df['total_annotations_Lat14087'] = merged_df['gloss_id_Lat14087']
merged_df['total_annotations_Lat7499'] = merged_df['gloss_id_Lat7499'] + merged_df['marginal_note_id_Lat7499']

merged_df = merged_df[['page', 'total_annotations_Lat14087', 'total_annotations_VLO41', 'total_annotations_Bamberg', 'total_annotations_Lat7499']]

# Set the style using Seaborn
sns.set(style='ticks')

# Create the area chart
plt.fill_between(merged_df['page'], merged_df['total_annotations_Lat7499'], label='Lat7499', color=colors[3], alpha=1.0, linewidth=3)
plt.fill_between(merged_df['page'], merged_df['total_annotations_Bamberg'], label='Bamberg', color=colors[1], alpha=0.8, linewidth=3)
plt.fill_between(merged_df['page'], merged_df['total_annotations_VLO41'], label='VLO41', color=colors[2], alpha=0.6, linewidth=3)
plt.fill_between(merged_df['page'], merged_df['total_annotations_Lat14087'], label='Lat14087', color=colors[0], alpha=0.4, linewidth=3)

# Set x-axis tick labels rotation
plt.xticks(rotation=80)

# Customize font size and style
plt.xlabel('Page', fontsize=14, fontweight='bold')
plt.ylabel('Total Annotations', fontsize=14, fontweight='bold')
plt.title('Diffusion of Annotations per manuscript: scale = Keil', fontsize=16, fontweight='bold')

# Customize legend
plt.legend(frameon=False)

# Set the figure background color
plt.gca().set_facecolor('#F0F0F0')

# Remove top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show gridlines
plt.grid(axis='y', linestyle='--', alpha=1.0)

# Add vertical lines at specified x-axis markers
x_markers = ['p453','p455', 'p458', 'p460', 'p462', 'p467']
for marker in x_markers:
    plt.axvline(x=marker, color='black', linestyle=':', linewidth=1.0)

# Adjust the layout for better spacing
plt.tight_layout()

plt.savefig('graphs/comparative_diffusion_mss_Keil.png')


plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define custom color palette
colors = ['#9619F3', '#DE2772', '#21F8EE', '#2E3FEF'] #'#F175AF'

# Concatenate the dataframes horizontally
merged_df = pd.concat([VLO41_diffusion_Keil['gloss'].rename('gloss_id_VLO41'), 
                       VLO41_diffusion_Keil['marginal_note_id'].rename('marginal_note_id_VLO41'),
                       Bamberg_diffusion_Keil['gloss'].rename('gloss_id_Bamberg'), 
                       Bamberg_diffusion_Keil['marginal_note_id'].rename('marginal_note_id_Bamberg'),
                       Lat14087_diffusion_Keil['gloss'].rename('gloss_id_Lat14087'),
                       Lat7499_diffusion_Keil['gloss'].rename('gloss_id_Lat7499'), 
                       Lat7499_diffusion_Keil['marginal_note_id'].rename('marginal_note_id_Lat7499')], axis=1, sort=False)

merged_df['page'] = Bamberg_diffusion_Keil['page']



# Calculate the total annotations per page by summing the values
merged_df['total_annotations_VLO41'] = merged_df['gloss_id_VLO41'] + merged_df['marginal_note_id_VLO41']
merged_df['total_annotations_Bamberg'] = merged_df['gloss_id_Bamberg'] + merged_df['marginal_note_id_Bamberg']
merged_df['total_annotations_Lat14087'] = merged_df['gloss_id_Lat14087']
merged_df['total_annotations_Lat7499'] = merged_df['gloss_id_Lat7499'] + merged_df['marginal_note_id_Lat7499']

merged_df = merged_df[['page', 'total_annotations_Lat14087', 'total_annotations_VLO41', 'total_annotations_Bamberg', 'total_annotations_Lat7499']]

# Filter the data up to 'page' 'p467'
filtered_df = merged_df[merged_df['page'] <= 'p468']

# Set the style using Seaborn
sns.set(style='ticks')

# Create the area chart using the filtered dataframe
plt.fill_between(filtered_df['page'], filtered_df['total_annotations_Lat7499'], label='Lat7499', color=colors[3], alpha=1.0, linewidth=2)
plt.fill_between(filtered_df['page'], filtered_df['total_annotations_Bamberg'], label='Bamberg', color=colors[1], alpha=0.8, linewidth=2)
plt.fill_between(filtered_df['page'], filtered_df['total_annotations_VLO41'], label='VLO41', color=colors[2], alpha=0.6, linewidth=2)
plt.fill_between(filtered_df['page'], filtered_df['total_annotations_Lat14087'], label='Lat14087', color=colors[0], alpha=0.4, linewidth=2)

# Set x-axis tick labels rotation
plt.xticks(rotation=80)

# Customize font size and style
plt.xlabel('Page', fontsize=14, fontweight='bold')
plt.ylabel('Total Annotations', fontsize=14, fontweight='bold')
plt.title('Diffusion of Annotations per manuscript: scale = Keil', fontsize=16, fontweight='bold')

# Customize legend
plt.legend(frameon=False)

# Set the figure background color
plt.gca().set_facecolor('#F0F0F0')

# Remove top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Show gridlines
plt.grid(axis='y', linestyle='--', alpha=1.0)

# Add vertical lines at specified x-axis markers
x_markers = ['p453','p455', 'p458', 'p460', 'p462', 'p468']
for marker in x_markers:
    plt.axvline(x=marker, color='black', linestyle=':', linewidth=1.0)

# Adjust the layout for better spacing
plt.tight_layout()

plt.savefig('graphs/comparative_diffusion_mss_Keil_firstbook.png')


plt.show()

# %%
VLO41 = pd.read_csv('/Users/vlachou/Desktop/ENC/MEMOIRE/Eutyches/comparative_mss_analysis/metadata_csv/VLO41.csv',encoding='utf-8')
Bamberg = pd.read_csv('/Users/vlachou/Desktop/ENC/MEMOIRE/Eutyches/comparative_mss_analysis/metadata_csv/Bamberg.csv',encoding='utf-8')
Lat14087 = pd.read_csv('/Users/vlachou/Desktop/ENC/MEMOIRE/Eutyches/comparative_mss_analysis/metadata_csv/Lat14087.csv',encoding='utf-8')
Lat7499 = pd.read_csv('/Users/vlachou/Desktop/ENC/MEMOIRE/Eutyches/comparative_mss_analysis/metadata_csv/Lat7499.csv',encoding='utf-8')

# %% [markdown]
# ### Role of marginalia in the entire dataset

# %%
# Assuming you have four dataframes: df1, df2, df3, df4

# Retrieve the "marginal_note_type" column from each dataframe
col1 = VLO41['marginal_note_type']
col2 = Bamberg['marginal_note_type']
col3 = Lat7499['marginal_note_type']

# Create a new dataframe with the retrieved columns
typologies_marginalia = pd.DataFrame({
    'VLO41': col1,
    'Bamberg': col2,
    'Lat7499': col3,
})

# Optional: Rename the columns if desired
typologies_marginalia.columns = ['marginal_note_type_VLO41', 'marginal_note_type_Bamberg', 'marginal_note_type_Lat7499']

# Print the new dataframe
typologies_marginalia
# Out:
#      marginal_note_type_VLO41 marginal_note_type_Bamberg  \
# 0                        S523                        S54
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ...                       ...                        ...
# 2035                      NaN                        NaN
# 2036                      NaN                        NaN
# 2037                      NaN                        NaN
# 2038                      NaN                        NaN
# 2039                      NaN                        NaN
#
#      marginal_note_type_Lat7499
# 0                          S523
# 1                           S23
# 2                           S23
# 3                          S631
# 4                           NaN
# ...                         ...
# 2035                        NaN
# 2036                        NaN
# 2037                        NaN
# 2038                        NaN
# 2039                        NaN
#
# [2040 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd


# Count the number of occurrences for each typology in all columns
typology_counts = typologies_marginalia.stack().value_counts()

# Filter typologies based on a threshold of minimum occurrences
threshold = typology_counts.median()
typology_counts_filtered = typology_counts[typology_counts >= threshold]

# Calculate the total count
total_count = typology_counts_filtered.sum()

# Calculate the percentage of each typology
typology_percentages = typology_counts_filtered / total_count * 100

# Sort the typologies by count in descending order
typology_counts_sorted = typology_counts_filtered.sort_values(ascending=False)

# Define the colors from the "Set2" color palette
colors = ['#66C2A5', '#FC8D62']

# Determine the color for each typology based on whether it counts more than the median
typology_colors = typology_counts_sorted.apply(lambda x: colors[0] if x > threshold else colors[1])

# Create a horizontal bar plot for typology percentages with different colors for median and above
plt.figure(figsize=(10, 6))
typology_counts_sorted.plot(kind='barh', color=typology_colors)
plt.xlabel('Count')
plt.ylabel('Typology')
plt.title('Count of Unique Marginalia Typologies (Threshold: Median)')
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# Retrieve the "marginal_note_type" column from each dataframe
col1 = VLO41['gloss_type']
col2 = Bamberg['gloss_type']
col3 = Lat7499['gloss_type']

# Create a new dataframe with the retrieved columns
typologies_glosses = pd.DataFrame({
    'VLO41': col1,
    'Bamberg': col2,
    'Lat7499': col3,
})

# Optional: Rename the columns if desired
typologies_glosses.columns = ['gloss_type_VLO41', 'gloss_type_Bamberg', 'gloss_type_Lat7499']

# Print the new dataframe
typologies_glosses
# Out:
#      gloss_type_VLO41 gloss_type_Bamberg gloss_type_Lat7499
# 0                 NaN                NaN                NaN
# 1                 S23                S22                S36
# 2                 S22                S22                S22
# 3                 S22                S22                S22
# 4                 S22                S22                S22
# ...               ...                ...                ...
# 2035              NaN                S23                NaN
# 2036              NaN               S221                NaN
# 2037              NaN               S221                NaN
# 2038              NaN               S221                NaN
# 2039              NaN                S23                NaN
#
# [2040 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have the typologies_marginalia dataframe

# Count the number of occurrences for each typology in all columns
typology_counts_glosses = typologies_glosses.stack().value_counts()

# Filter typologies based on a threshold of minimum occurrences
threshold = 10
typology_counts_filtered = typology_counts_glosses[typology_counts_glosses >= threshold]

# Calculate the total count
total_count = typology_counts_filtered.sum()

# Calculate the percentage of each typology
typology_percentages = typology_counts_filtered / total_count * 100

# Sort the typologies by count in descending order
typology_counts_sorted = typology_counts_filtered.sort_values(ascending=False)

# Define the colors from the "Set2" color palette
colors = ['#66C2A5', '#FC8D62']

# Determine the color for each typology based on whether it counts more than the threshold
typology_colors = typology_counts_sorted.apply(lambda x: colors[0] if x > threshold else colors[1])

# Create a horizontal bar plot for typology percentages with different colors for threshold and above
plt.figure(figsize=(10, 6))
typology_counts_sorted.plot(kind='barh', color=typology_colors)
plt.xlabel('Count')
plt.ylabel('Typology')
plt.title('Count of Unique Gloss Typologies (Threshold: 10 occurrences)')
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import entropy

# Define the dataframes
dataframes = [
    VLO41,
    Bamberg,
    Lat14087,
    Lat7499
]

# Define the names of the dataframes
df_names = [
    'VLO41',
    'Bamberg',
    'Lat14087',
    'Lat7499'
]

# Calculate the richness/variety of annotations (entropy-based) and text length (number of lemmas) for each DataFrame
annotation_richness = []
lemmas_length = []

for df in dataframes:
    lemmas = df['lemma_id']
    
    if 'marginal_note_type' in df.columns:
        typologies = df[['gloss_type', 'marginal_note_type']].values.flatten()
    else:
        typologies = df['gloss_type'].values.flatten()
        
    typologies_counts = pd.Series(typologies).value_counts(normalize=True)
    entropy_val = entropy(typologies_counts, base=2)
    annotation_richness.append(entropy_val)
    lemmas_length.append(len(lemmas))

# Create a scatter plot to visualize the relationship between text length and richness of annotations
fig, ax = plt.subplots()
scatter = ax.scatter(text_length, annotation_richness, c=annotation_richness, cmap='viridis', s=80)

# Add labels for each point on the scatter plot with different colors based on variety
for i, mss in enumerate(df_names):
    ax.annotate(mss, (text_length[i], annotation_richness[i]), ha='center', va='bottom')
    

# Add a curve to represent the non-linear relationship
curve_fit = np.polyfit(text_length, lexical_richness, deg=2)
curve_x = np.linspace(min(text_length), max(text_length), 100)
curve_y = np.polyval(curve_fit, curve_x)
ax.plot(curve_x, curve_y, color='black', linestyle='--')

# Set plot labels and title
ax.set_xlabel('Number of Lemmas glossed')
ax.set_ylabel("Typology Richness (Shannon's Entropy Index)")
ax.set_title('Relationship between Amount of Lemmas and Typology Richness')

# Add a colorbar legend
cbar = plt.colorbar(scatter)
cbar.set_label('Typology Richness')

plt.savefig('graphs/lemmas_variety_shannons_entropy.png')


plt.show()

# %% [markdown]
# ### Let's start by making one by one comparative applications on typology and form to pairs of manuscritps and then merge everything together

# %%
merged_df_VLO_Bamberg = pd.merge(VLO41, Bamberg, on='lemma_id', suffixes=('_VLO41', '_Bamberg'))
merged_df_VLO_Bamberg
# Out:
#          lemma_id folio_VLO41                                   lemma_VLO41  \
# 0    p447_l01_o00         02r  INCIPIT LIBER EVTI/CI GRAMMAT(I)CI /DE VERBO
# 1    p447_l05_o02         02r                                        semper
# 2    p447_l05_o04         02r                             nouas quaestiones
# 3    p447_l05_o05         02r                                     doctorib;
# 4    p447_l05_o06         02r                                     auditorum
# ..            ...         ...                                           ...
# 559  p470_l23_o05         22r                                      bacchor
# 560  p471_l03_o08         22r                                        foedus
# 561  p471_l26_o01         22v                                         trudo
# 562  p476_l07_o09         25r                                         pango
# 563  p476_l12_o04         25r                                         purgo
#
#               gloss_VLO41 gloss_type_VLO41 gloss_form_VLO41  \
# 0                     NaN              NaN              NaN
# 1       s. cũ frequentia              S23               F3
# 2    novẽ int̃rogaciones              S22               F3
# 3          p̃ce<ptoribus>              S22               F2
# 4         iđ discipulorũ              S22               F2
# ..                    ...              ...              ...
# 559       furo ł insanior              S22               F3
# 560                turpis              S22               F2
# 561              impello               S22               F2
# 562                   NaN              NaN              NaN
# 563               a purg̃             S611               F3
#
#                                 marginal_note_id_VLO41  \
# 0              ++++/de uer[bo] ++++/[bo]nus contextor
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 559                                                NaN
# 560                                                NaN
# 561                                                NaN
# 562  ille poematu pconpanpango oratius epistularum ...
# 563                                                NaN
#
#     marginal_note_type_VLO41 marginal_note_form_VLO41 folio_Bamberg  \
# 0                       S523                       F4           71r
# 1                        NaN                      NaN           71r
# 2                        NaN                      NaN           71r
# 3                        NaN                      NaN           71r
# 4                        NaN                      NaN           71r
# ..                       ...                      ...           ...
# 559                      NaN                      NaN           80r
# 560                      NaN                      NaN           80r
# 561                      NaN                      NaN           80r
# 562                      S72                       F4           81v
# 563                      NaN                      NaN           81v
#
#     lemma_Bamberg        gloss_id         gloss_Bamberg gloss_type_Bamberg  \
# 0        EVTICII              NaN                   NaN                NaN
# 1         SEMPER   p447_l05_o02_a                ꝓ sepe                S22
# 2     QVĘSTIONES   p447_l05_o04_a          ꝓ positiones                S22
# 3     DOCTORIBVS   p447_l05_o05_a  PRAECEP ͭ ͦ ͬ ͥᵇ ͧ ᷤ                S22
# 4      AVDITORVM   p447_l05_o06_a          discipulorũ                S22
# ..            ...             ...                   ...                ...
# 559      Bacchor   p470_l23_o05_a               insanio                S22
# 560        Fedus   p471_l03_o08_a                turpis                S22
# 561        Trudo   p471_l26_o01_a                indudo                S22
# 562        pango   p476_l07_o09_a                cõpono                S22
# 563        purgo   p476_l12_o04_a                 mundo                S22
#
#     gloss_form_Bamberg     nature marginal_note_id_Bamberg  \
# 0                  NaN        NaN           p447_l01_o00_a
# 1                   F2     normal                      NaN
# 2                   F2     normal                      NaN
# 3                   F2  shorthand                      NaN
# 4                   F2     normal                      NaN
# ..                 ...        ...                      ...
# 559                 F2     normal           p470_l23_o05_b
# 560                 F2     normal                      NaN
# 561                 F2     normal                      NaN
# 562                 F2     normal           p476_l07_o09_b
# 563                 F2     normal                      NaN
#
#     marginal_note_type_Bamberg marginal_note_form_Bamberg
# 0                          S54                         F5
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ..                         ...                        ...
# 559                        S63                         F2
# 560                        NaN                        NaN
# 561                        NaN                        NaN
# 562                        S63                         F2
# 563                        NaN                        NaN
#
# [564 rows x 19 columns]

# %%
# Filter the rows where the conditions are met
common_VLO41_Bamberg = merged_df_VLO_Bamberg[
    (merged_df_VLO_Bamberg['gloss_type_VLO41'] == merged_df_VLO_Bamberg['gloss_type_Bamberg']) &
    ((merged_df_VLO_Bamberg['gloss_form_VLO41'] == merged_df_VLO_Bamberg['gloss_form_Bamberg']) |
    (merged_df_VLO_Bamberg['marginal_note_type_VLO41'] == merged_df_VLO_Bamberg['marginal_note_type_Bamberg']))
]

# Select the desired columns
common_VLO41_Bamberg = common_VLO41_Bamberg[['lemma_id', 'gloss_type_VLO41', 'gloss_type_Bamberg',
                                             'gloss_form_VLO41', 'gloss_form_Bamberg']]

# Merge with merged_df_VLO41_Bamberg to get 'lemma_VLO41' and 'lemma_Bamberg'
common_VLO41_Bamberg = common_VLO41_Bamberg.merge(merged_df_VLO_Bamberg[['lemma_id', 'lemma_VLO41', 'gloss_VLO41', 'lemma_Bamberg', 'gloss_Bamberg']],
                                                  on='lemma_id', how='left')

# Display the new DataFrame
common_VLO41_Bamberg.to_csv('identical_glosses_csv/identical_glosses_VLO41_Bamberg.csv')
common_VLO41_Bamberg
# Out:
#          lemma_id gloss_type_VLO41 gloss_type_Bamberg gloss_form_VLO41  \
# 0    p447_l05_o05              S22                S22               F2
# 1    p447_l05_o06              S22                S22               F2
# 2    p447_l06_o05              S22                S22               F2
# 3    p447_l07_o01              S22                S22               F2
# 4    p447_l07_o03              S22                S22               F2
# ..            ...              ...                ...              ...
# 233  p466_l22_o02              S22                S22               F2
# 234  p468_l15_o10              S22                S22               F2
# 235  p470_l09_o07              S22                S22               F2
# 236  p471_l03_o08              S22                S22               F2
# 237  p471_l26_o01              S22                S22               F2
#
#     gloss_form_Bamberg lemma_VLO41       gloss_VLO41 lemma_Bamberg  \
# 0                   F2   doctorib;    p̃ce<ptoribus>   DOCTORIBVS
# 1                   F2   auditorum   iđ discipulorũ    AVDITORVM
# 2                   F2  curiositas  qͣsi sollicitudo   curiositas
# 3                   F2   desiderat             cupit     desider&
# 4                   F2      recens         nouit(er)       recens
# ..                 ...         ...               ...           ...
# 233                 F2   adipiscor        inueniscor    adipiscor
# 234                 F2        neco        interficio         neco
# 235                 F2      glisco            cresco       Glisco
# 236                 F2      foedus            turpis        Fedus
# 237                 F2       trudo          impello         Trudo
#
#                   gloss_Bamberg
# 0          PRAECEP ͭ ͦ ͬ ͥᵇ ͧ ᷤ
# 1                  discipulorũ
# 2    (a cora) sagax sollicitudo
# 3                    c̃cupiscat
# 4                         nouum
# ..                          ...
# 233                   consequor
# 234                   int̃ficio
# 235                      cresco
# 236                      turpis
# 237                      indudo
#
# [238 rows x 9 columns]

# %%
merged_df_VLO_Bamberg['page'] = merged_df_VLO_Bamberg['lemma_id'].str.extract(r'(p\d+)')
subset_VLO41Bamberg = merged_df_VLO_Bamberg[['page','lemma_id', 'gloss_form_VLO41','gloss_form_Bamberg']]
subset_VLO41Bamberg = subset_VLO41Bamberg.dropna()

# Convert F1-5 to numerical values 1-5
subset_VLO41Bamberg['gloss_form_VLO41'] = subset_VLO41Bamberg['gloss_form_VLO41'].str.extract('(\d)').astype(int)
subset_VLO41Bamberg['gloss_form_Bamberg'] = subset_VLO41Bamberg['gloss_form_Bamberg'].str.extract('(\d)').astype(int)

# Calculate the stability, increase, and decrease ratios
stable_ratio = (subset_VLO41Bamberg['gloss_form_VLO41'] == subset_VLO41Bamberg['gloss_form_Bamberg']).mean()
increase_ratio = (subset_VLO41Bamberg['gloss_form_VLO41'] < subset_VLO41Bamberg['gloss_form_Bamberg']).mean()
decrease_ratio = (subset_VLO41Bamberg['gloss_form_VLO41'] > subset_VLO41Bamberg['gloss_form_Bamberg']).mean()

# Print the ratios
print("Stable Ratio: {:.2%}".format(stable_ratio))
print("Increase Ratio: {:.2%}".format(increase_ratio))
print("Decrease Ratio: {:.2%}".format(decrease_ratio))
# Out:
# Stable Ratio: 52.78%
# Increase Ratio: 19.19%
# Decrease Ratio: 28.02%

# %% [markdown]
# ### More can be done, but let's move to the next one

# %%
merged_df_VLO_Lat7499 = pd.merge(VLO41, Lat7499, on='lemma_id', suffixes=('_VLO41', '_Lat7499'))
merged_df_VLO_Lat7499
# Out:
#          lemma_id folio_VLO41                                   lemma_VLO41  \
# 0    p447_l01_o00         02r  INCIPIT LIBER EVTI/CI GRAMMAT(I)CI /DE VERBO
# 1    p447_l05_o02         02r                                        semper
# 2    p447_l05_o04         02r                             nouas quaestiones
# 3    p447_l05_o05         02r                                     doctorib;
# 4    p447_l05_o06         02r                                     auditorum
# ..            ...         ...                                           ...
# 639  p466_l06_o03         18v                                         rimor
# 640  p466_l21_o09         19r                                      paciscor
# 641  p466_l22_o02         19r                                     adipiscor
# 642  p470_l09_o07         21v                                        glisco
# 643  p471_l26_o01         22v                                         trudo
#
#               gloss_VLO41 gloss_type_VLO41 gloss_form_VLO41  \
# 0                     NaN              NaN              NaN
# 1       s. cũ frequentia              S23               F3
# 2    novẽ int̃rogaciones              S22               F3
# 3          p̃ce<ptoribus>              S22               F2
# 4         iđ discipulorũ              S22               F2
# ..                    ...              ...              ...
# 639              ꝑscrutor              S22               F2
# 640           pactũ facio              S23               F4
# 641            inueniscor              S22               F2
# 642                cresco              S22               F2
# 643              impello               S22               F2
#
#                       marginal_note_id_VLO41 marginal_note_type_VLO41  \
# 0    ++++/de uer[bo] ++++/[bo]nus contextor                      S523
# 1                                        NaN                      NaN
# 2                                        NaN                      NaN
# 3                                        NaN                      NaN
# 4                                        NaN                      NaN
# ..                                       ...                      ...
# 639                                      NaN                      NaN
# 640                                      NaN                      NaN
# 641                                      NaN                      NaN
# 642                                      NaN                      NaN
# 643                                      NaN                      NaN
#
#     marginal_note_form_VLO41 folio_Lat7499 lemma_Lat7499        gloss_id  \
# 0                         F4           73r      EVTICII   p447_l01_o00_a
# 1                        NaN           73r       SEMPER   p447_l05_o02_a
# 2                        NaN           73r   QVESTIONES   p447_l05_o04_a
# 3                        NaN           73r    DOCTORIB   p447_l05_o05_a
# 4                        NaN           73r    AVDITORṼ   p447_l05_o06_a
# ..                       ...           ...           ...             ...
# 639                      NaN           84v        Rimor   p466_l06_o03_a
# 640                      NaN           84v      pacisor   p466_l21_o09_a
# 641                      NaN           84v   Adipiscor;   p466_l22_o02_a
# 642                      NaN           85v       Glisco   p470_l09_o07_a
# 643                      NaN           86r        Trudo   p471_l26_o01_a
#
#                            gloss_Lat7499 gloss_type_Lat7499  \
# 0    Eutex euticis. Inde euticius eutici                S54
# 1                                 ꝓ sepe                S22
# 2                          ÷ ꝓpositiones                S22
# 3                  magistris p̃ceptorib                S22
# 4                             discipuloꝵ                S22
# ..                                   ...                ...
# 639                               inqͥro                S22
# 640                          pacẽ fatio                S23
# 641                    consequor inuenio                S22
# 642                               cresco                S22
# 643              includo impingo ł pello                S22
#
#     gloss_form_Lat7499 marginal_note_id_Lat7499 marginal_note_type_Lat7499  \
# 0                   F3                      NaN                        NaN
# 1                   F2           p447_l05_o02_b                        S23
# 2                   F2           p447_l05_o04_b                       S631
# 3                   F3                      NaN                        NaN
# 4                   F2                      NaN                        NaN
# ..                 ...                      ...                        ...
# 639                 F2                      NaN                        NaN
# 640                 F4                      NaN                        NaN
# 641                 F3                      NaN                        NaN
# 642                 F2                      NaN                        NaN
# 643                 F3                      NaN                        NaN
#
#     marginal_note_form_Lat7499
# 0                          NaN
# 1                           F5
# 2                           F5
# 3                          NaN
# 4                          NaN
# ..                         ...
# 639                        NaN
# 640                        NaN
# 641                        NaN
# 642                        NaN
# 643                        NaN
#
# [644 rows x 18 columns]

# %%
# Filter the rows where the conditions are met
common_VLO41_Lat7499 = merged_df_VLO_Lat7499[
    (merged_df_VLO_Lat7499['gloss_type_VLO41'] == merged_df_VLO_Lat7499['gloss_type_Lat7499']) &
    ((merged_df_VLO_Lat7499['gloss_form_VLO41'] == merged_df_VLO_Lat7499['gloss_form_Lat7499']) |
    (merged_df_VLO_Lat7499['marginal_note_type_VLO41'] == merged_df_VLO_Lat7499['marginal_note_type_Lat7499']))
]

# Select the desired columns
common_VLO41_Lat7499 = common_VLO41_Lat7499[['lemma_id', 'gloss_type_VLO41', 'gloss_type_Lat7499',
                                             'gloss_form_VLO41', 'gloss_form_Lat7499']]

# Merge with merged_df_VLO41_Bamberg to get 'lemma_VLO41' and 'lemma_Bamberg'
common_VLO41_Lat7499 = common_VLO41_Lat7499.merge(merged_df_VLO_Lat7499[['lemma_id', 'lemma_VLO41', 'gloss_VLO41', 'lemma_Lat7499', 'gloss_Lat7499']],
                                                  on='lemma_id', how='left')

# Display the new DataFrame
common_VLO41_Lat7499.to_csv('identical_glosses_csv/identical_glosses_VLO41_Lat7499.csv')
common_VLO41_Lat7499
# Out:
#          lemma_id gloss_type_VLO41 gloss_type_Lat7499 gloss_form_VLO41  \
# 0    p447_l05_o06              S22                S22               F2
# 1    p447_l05_o08              S22                S22               F3
# 2    p447_l07_o01              S22                S22               F2
# 3    p447_l07_o03              S22                S22               F2
# 4    p447_l09_o05             S553               S553               F3
# ..            ...              ...                ...              ...
# 227  p463_l25_o09              S22                S22               F2
# 228  p464_l13_o09              S22                S22               F2
# 229  p466_l06_o03              S22                S22               F2
# 230  p466_l21_o09              S23                S23               F4
# 231  p470_l09_o07              S22                S22               F2
#
#     gloss_form_Lat7499 lemma_VLO41            gloss_VLO41 lemma_Lat7499  \
# 0                   F2   auditorum        iđ discipulorũ    AVDITORṼ
# 1                   F3   cõmouere   reperire et excitare     commouere
# 2                   F2   desiderat                  cupit    desideret
# 3                   F2      recens              nouit(er)       recens
# 4                   F3     Cratere             nom̃ ꝓpͥũ      CRATERE
# ..                 ...         ...                    ...           ...
# 227                 F2      metior                mensuro       metior
# 228                 F2        eger               infirmus         ager
# 229                 F2       rimor               ꝑscrutor        Rimor
# 230                 F4    paciscor            pactũ facio      pacisor
# 231                 F2      glisco                 cresco       Glisco
#
#           gloss_Lat7499
# 0            discipuloꝵ
# 1    suscitare incitare
# 2            .s. audire
# 3                 Nouũ
# 4            ꝓpͥũ nom̃
# ..                  ...
# 227           ÷ mensuro
# 228             infirmꝰ
# 229              inqͥro
# 230         pacẽ fatio
# 231              cresco
#
# [232 rows x 9 columns]

# %%
merged_df_VLO_Lat7499['page'] = merged_df_VLO_Lat7499['lemma_id'].str.extract(r'(p\d+)')
subset_VLO41Lat7499 = merged_df_VLO_Lat7499[['page','lemma_id', 'gloss_form_VLO41','gloss_form_Lat7499']]
subset_VLO41Lat7499 = subset_VLO41Lat7499.dropna()

# Convert F1-5 to numerical values 1-5
subset_VLO41Lat7499['gloss_form_VLO41'] = subset_VLO41Lat7499['gloss_form_VLO41'].str.extract('(\d)').astype(int)
subset_VLO41Lat7499['gloss_form_Lat7499'] = subset_VLO41Lat7499['gloss_form_Lat7499'].str.extract('(\d)').astype(int)

# Calculate the stability, increase, and decrease ratios
stable_ratio = (subset_VLO41Lat7499['gloss_form_VLO41'] == subset_VLO41Lat7499['gloss_form_Lat7499']).mean()
increase_ratio = (subset_VLO41Lat7499['gloss_form_VLO41'] < subset_VLO41Lat7499['gloss_form_Lat7499']).mean()
decrease_ratio = (subset_VLO41Lat7499['gloss_form_VLO41'] > subset_VLO41Lat7499['gloss_form_Lat7499']).mean()

# Print the ratios
print("Stable Ratio: {:.2%}".format(stable_ratio))
print("Increase Ratio: {:.2%}".format(increase_ratio))
print("Decrease Ratio: {:.2%}".format(decrease_ratio))
# Out:
# Stable Ratio: 48.91%
# Increase Ratio: 36.39%
# Decrease Ratio: 14.69%

# %% [markdown]
# ### More can be done, but let's move to the next one

# %%
merged_df_VLO_Lat14087 = pd.merge(VLO41, Lat14087, on='lemma_id', suffixes=('_VLO41', '_Lat14087'))
merged_df_VLO_Lat14087
# Out:
#          lemma_id folio         lemma                 gloss_VLO41  \
# 0    p447_l05_o05   02r     doctorib;              p̃ce<ptoribus>
# 1    p447_l05_o06   02r     auditorum             iđ discipulorũ
# 2    p447_l18_o05   02r     BARIΘONOC                grauis sonus
# 3    p448_l02_o08   02r  ΠE/ΡΙCΠΟΜΕΝΕ  ꝑicpomene circũflexibilis
# 4    p448_l20_o07   02v         sodes                    si audes
# ..            ...   ...           ...                         ...
# 137  p465_l28_o07   18r       amitior                        tego
# 138  p466_l05_o04   18v         uador                       error
# 139  p466_l21_o09   19r      paciscor                 pactũ facio
# 140  p466_l22_o02   19r     adipiscor                  inueniscor
# 141  p468_l32_o04   20v          dico                        dono
#
#     gloss_type_VLO41 gloss_form_VLO41 marginal_note_id marginal_note_type  \
# 0                S22               F2              NaN                NaN
# 1                S22               F2              NaN                NaN
# 2               S211               F3              NaN                NaN
# 3               S211               F3              NaN                NaN
# 4                S23               F3              NaN                NaN
# ..               ...              ...              ...                ...
# 137              S22               F2              NaN                NaN
# 138              S22               F2              NaN                NaN
# 139              S23               F4              NaN                NaN
# 140              S22               F2              NaN                NaN
# 141              S22               F2              NaN                NaN
#
#     marginal_note_form                                     gloss_Lat14087  \
# 0                  NaN                       Preceptor. doctor ł magifter
# 1                  NaN                               Adiutor/ discipulus
# 2                  NaN                            Barithonos/Aliena atona
# 3                  NaN                      Perspomene. quasi circũ flexo
# 4                  NaN                                           si audes
# ..                 ...                                                ...
# 137                NaN                Amicior . Vestio circũdo induo togo
# 138                NaN               Vador. ꝓmitto. causã ago. fidẽ fatio
# 139                NaN                         Pasciscor pacẽ redintegror
# 140                NaN    Adipiscor conor / Nasiciscor Adipiscor Assequor
# 141                NaN  Dico dicas :consecro uł dono / dico dicis : Narro
#
#     gloss_type_Lat14087 gloss_form_Lat14087
# 0                   S22                  F3
# 1                   S23                  F2
# 2                   S23                  F3
# 3                  S211                  F3
# 4                   S25                  F3
# ..                  ...                 ...
# 137                 S22                  F3
# 138                 S23                  F4
# 139                 S23                  F4
# 140                 S22                  F3
# 141                 S23                  F3
#
# [142 rows x 12 columns]

# %%
# Filter the rows where the conditions are met
common_VLO41_Lat14087 = merged_df_VLO_Lat14087[
    (merged_df_VLO_Lat14087['gloss_type_VLO41'] == merged_df_VLO_Lat14087['gloss_type_Lat14087']) &
    ((merged_df_VLO_Lat14087['gloss_form_VLO41'] == merged_df_VLO_Lat14087['gloss_form_Lat14087']))
]

# Select the desired columns
common_VLO41_Lat14087 = common_VLO41_Lat14087[['lemma_id', 'gloss_type_VLO41', 'gloss_type_Lat14087',
                                             'gloss_form_VLO41', 'gloss_form_Lat14087']]

# Merge with merged_df_VLO41_Bamberg to get 'lemma_VLO41' and 'lemma_Bamberg'
common_VLO41_Lat14087 = common_VLO41_Lat14087.merge(merged_df_VLO_Lat14087[['lemma_id', 'lemma', 'gloss_VLO41', 'gloss_Lat14087']],
                                                  on='lemma_id', how='left')

# Display the new DataFrame
common_VLO41_Lat14087.to_csv('identical_glosses_csv/identical_glosses_VLO41_Lat14087.csv')
common_VLO41_Lat14087
# Out:
#         lemma_id gloss_type_VLO41 gloss_type_Lat14087 gloss_form_VLO41  \
# 0   p448_l02_o08             S211                S211               F3
# 1   p450_l02_o04              S22                 S22               F2
# 2   p450_l06_o07              S22                 S22               F2
# 3   p450_l26_o01              S22                 S22               F3
# 4   p451_l11_o04              S22                 S22               F3
# 5   p451_l12_o02              S22                 S22               F2
# 6   p451_l12_o03              S22                 S22               F2
# 7   p451_l22_o06              S22                 S22               F2
# 8   p451_l23_o05              S22                 S22               F2
# 9   p452_l16_o06              S22                 S22               F3
# 10  p452_l17_o02              S22                 S22               F3
# 11  p452_l22_o04              S23                 S23               F3
# 12  p453_l10_o11              S22                 S22               F3
# 13  p453_l20_o06              S22                 S22               F3
# 14  p453_l29_o08              S22                 S22               F3
# 15  p453_l30_o04              S22                 S22               F3
# 16  p454_l17_o07              S23                 S23               F4
# 17  p455_l30_o02              S22                 S22               F2
# 18  p456_l06_o08              S22                 S22               F3
# 19  p457_l19_o02              S23                 S23               F3
# 20  p457_l21_o11              S22                 S22               F3
# 21  p457_l26_o07              S22                 S22               F3
# 22  p458_l05_o07              S22                 S22               F3
# 23  p458_l12_o02              S22                 S22               F2
# 24  p458_l21_o06              S22                 S22               F2
# 25  p458_l29_o09              S22                 S22               F2
# 26  p461_l10_o04              S22                 S22               F3
# 27  p462_l06_o07              S22                 S22               F2
# 28  p462_l07_o05              S22                 S22               F2
# 29  p463_l25_o02              S22                 S22               F2
# 30  p465_l25_o11              S22                 S22               F2
# 31  p466_l21_o09              S23                 S23               F4
#
#    gloss_form_Lat14087         lemma                       gloss_VLO41  \
# 0                   F3  ΠE/ΡΙCΠΟΜΕΝΕ        ꝑicpomene circũflexibilis
# 1                   F2       enucleo                            aperio
# 2                   F2        fatuo                            desinio
# 3                   F3           pio                       purgo/mundo
# 4                   F3      insignio                      orno/redimio
# 5                   F2         Sopio                            dormio
# 6                   F2         Ferio                            ꝑcucio
# 7                   F2         fodio                             ꝑforo
# 8                   F2        potior                              utor
# 9                   F3     sacrifico               libo/aliqͣ  oblatio
# 10                  F3     participo               mancipo cõm(unico)
# 11                  F3    iusticium                    luctus publicus
# 12                  F3        marceo  defitio areo tabesco siue macior
# 13                  F3      fluuidus                decurrens ł fluens
# 14                  F3      efutilis                 uacuus instabilis
# 15                  F3          cedo               paucior ãbulo / in
# 16                  F4       pronuba         mulier ꝗ disponit nuptias
# 17                  F2        fultor                       sustentator
# 18                  F3       altilis                  ++++ ł saginatus
# 19                  F3       nundine                    mercata pubica
# 20                  F3         multo                     uindico punio
# 21                  F3         prob;            idoneus strenuus sagax
# 22                  F3     stomachor               irascor /ł  insanio
# 23                  F2       integro                          perfitio
# 24                  F2         ubero                            abundo
# 25                  F2        testor                          confirmo
# 26                  F3          humo                  sepelio/cooperio
# 27                  F2         uello                              rũpo
# 28                  F2       nutrico                               alo
# 29                  F2          meta                             limes
# 30                  F2     polliceor                            ꝓmitto
# 31                  F4      paciscor                       pactũ facio
#
#                                        gloss_Lat14087
# 0                       Perspomene. quasi circũ flexo
# 1                                      Nucleo. claudo
# 2                                      fatuor hebesco
# 3                                     Pio purgo placo
# 4                           insignior. orno. nobilito
# 5                                        Sopio Dormio
# 6                                     Exsicco ł ferio
# 7                                     fodio ł colligo
# 8                                        Potior fruor
# 9                         libo sacrifico uel deglisto
# 10           inꝑcior. ł comunico. Adiuuo ł consortior
# 11  Iustitum publicus luctus ł puiblici iuris silentũ
# 12                            Marceo. langueo. ł areo
# 13                    fluens decurrens solutus humor;
# 14    Effutilis inutilis ł in stablis uanꝰ ł loquax;
# 15                             Cedo transigo conficio
# 16     ꝓnuba. quę nubentibus p̃÷ łquae utrũq c̃iugit;
# 17                                 Flutor sustentator
# 18                          Altilis studiose saginatꝰ
# 19              Nundinę loca mercati id ÷ argisteria.
# 20                    condẽpno uexo. lacero ł iterimo
# 21  ꝓbus. benemoratꝰ. honestus. Festiuus decens . ...
# 22                      Stomachor . lacero . lrascor.
# 23                                  integror. Reparo.
# 24                                    Exuberor abundo
# 25                                  Detestor abominor
# 26                         Humo humi trado ł sepelio.
# 27                                        Vello moueo
# 28                                        Nt̃co iurgo
# 29                                          M&a finis
# 30                                 ꝓmitto polliceor.
# 31                         Pasciscor pacẽ redintegror

# %%
merged_df_VLO_Lat14087['page'] = merged_df_VLO_Lat14087['lemma_id'].str.extract(r'(p\d+)')
subset_VLO41Lat14087 = merged_df_VLO_Lat14087[['page','lemma_id', 'gloss_form_VLO41','gloss_form_Lat14087']]
subset_VLO41Lat14087 = subset_VLO41Lat14087.dropna()

# Convert F1-5 to numerical values 1-5
subset_VLO41Lat14087['gloss_form_VLO41'] = subset_VLO41Lat14087['gloss_form_VLO41'].str.extract('(\d)').astype(int)
subset_VLO41Lat14087['gloss_form_Lat14087'] = subset_VLO41Lat14087['gloss_form_Lat14087'].str.extract('(\d)').astype(int)

# Calculate the stability, increase, and decrease ratios
stable_ratio = (subset_VLO41Lat14087['gloss_form_VLO41'] == subset_VLO41Lat14087['gloss_form_Lat14087']).mean()
increase_ratio = (subset_VLO41Lat14087['gloss_form_VLO41'] < subset_VLO41Lat14087['gloss_form_Lat14087']).mean()
decrease_ratio = (subset_VLO41Lat14087['gloss_form_VLO41'] > subset_VLO41Lat14087['gloss_form_Lat14087']).mean()

# Print the ratios
print("Stable Ratio: {:.2%}".format(stable_ratio))
print("Increase Ratio: {:.2%}".format(increase_ratio))
print("Decrease Ratio: {:.2%}".format(decrease_ratio))
# Out:
# Stable Ratio: 38.41%
# Increase Ratio: 42.75%
# Decrease Ratio: 18.84%

# %% [markdown]
# ### More can be done, but let's move to the next one

# %%
merged_df_Bamberg_Lat7499 = pd.merge(Bamberg, Lat7499, on='lemma_id', suffixes=('_Bamberg', '_Lat7499'))
merged_df_Bamberg_Lat7499
# Out:
#      folio_Bamberg         lemma_id lemma_Bamberg gloss_id_Bamberg  \
# 0              71r     p447_l01_o00      EVTICII               NaN
# 1              71r     p447_l05_o02       SEMPER    p447_l05_o02_a
# 2              71r     p447_l05_o04   QVĘSTIONES    p447_l05_o04_a
# 3              71r     p447_l05_o05   DOCTORIBVS    p447_l05_o05_a
# 4              71r     p447_l05_o06    AVDITORVM    p447_l05_o06_a
# ...            ...              ...           ...              ...
# 1098           83r  p482_l11_o01-02     in .ror.               NaN
# 1099           83r  p482_l14_o01-02      in .so.               NaN
# 1100           83v     p483_l20_o04       Exulto    p483_l20_o04_a
# 1101           84r  p485_l20_o04-05     in .xor.               NaN
# 1102           84v     p486_l28_o07        motus    p486_l28_o07_a
#
#              gloss_Bamberg gloss_type_Bamberg gloss_form_Bamberg     nature  \
# 0                      NaN                NaN                NaN        NaN
# 1                   ꝓ sepe                S22                 F2     normal
# 2             ꝓ positiones                S22                 F2     normal
# 3     PRAECEP ͭ ͦ ͬ ͥᵇ ͧ ᷤ                S22                 F2  shorthand
# 4             discipulorũ                S22                 F2     normal
# ...                    ...                ...                ...        ...
# 1098                   NaN                NaN                NaN        NaN
# 1099                   NaN                NaN                NaN        NaN
# 1100                  l&or                S22                 F2     normal
# 1101                   NaN                NaN                NaN        NaN
# 1102                     +                S22                 F2     normal
#
#      marginal_note_id_Bamberg marginal_note_type_Bamberg  \
# 0              p447_l01_o00_a                        S54
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ...                       ...                        ...
# 1098        p482_l11_o01-02_a                        S63
# 1099        p482_l14_o01-02_a                        S63
# 1100                      NaN                        NaN
# 1101        p485_l20_o04-05_a                        S63
# 1102                      NaN                        NaN
#
#      marginal_note_form_Bamberg folio_Lat7499  \
# 0                            F5           73r
# 1                           NaN           73r
# 2                           NaN           73r
# 3                           NaN           73r
# 4                           NaN           73r
# ...                         ...           ...
# 1098                         F3           89v
# 1099                         F3           89v
# 1100                        NaN           90r
# 1101                         F2           90v
# 1102                        NaN           91r
#
#                                   lemma_Lat7499 gloss_id_Lat7499  \
# 0                                      EVTICII    p447_l01_o00_a
# 1                                       SEMPER    p447_l05_o02_a
# 2                                   QVESTIONES    p447_l05_o04_a
# 3                                    DOCTORIB    p447_l05_o05_a
# 4                                    AVDITORṼ    p447_l05_o06_a
# ...                                         ...              ...
# 1098                                  in .ror.               NaN
# 1099                                   In .so.               NaN
# 1100                                   exultat    p483_l20_o04_a
# 1101  \n                              In .xor.               NaN
# 1102                                    motus.    p486_l28_o07_a
#
#                             gloss_Lat7499 gloss_type_Lat7499  \
# 0     Eutex euticis. Inde euticius eutici                S54
# 1                                  ꝓ sepe                S22
# 2                           ÷ ꝓpositiones                S22
# 3                   magistris p̃ceptorib                S22
# 4                              discipuloꝵ                S22
# ...                                   ...                ...
# 1098                                  NaN                NaN
# 1099                                  NaN                NaN
# 1100                                    s               S611
# 1101                                  NaN                NaN
# 1102                             ł meatus                S22
#
#      gloss_form_Lat7499 marginal_note_id_Lat7499 marginal_note_type_Lat7499  \
# 0                    F3                      NaN                        NaN
# 1                    F2           p447_l05_o02_b                        S23
# 2                    F2           p447_l05_o04_b                       S631
# 3                    F3                      NaN                        NaN
# 4                    F2                      NaN                        NaN
# ...                 ...                      ...                        ...
# 1098                NaN        p482_l14_o01-02_a                        S63
# 1099                NaN                      NaN                        NaN
# 1100                 F1                      NaN                        NaN
# 1101                NaN        p485_l20_o04-05_a                        S63
# 1102                 F2                      NaN                        NaN
#
#      marginal_note_form_Lat7499
# 0                           NaN
# 1                            F5
# 2                            F5
# 3                           NaN
# 4                           NaN
# ...                         ...
# 1098                         F1
# 1099                        NaN
# 1100                        NaN
# 1101                         F3
# 1102                        NaN
#
# [1103 rows x 20 columns]

# %% [markdown]
# ### Let's see out of the total common lemmas glossed, how many in Bamberg correspond to tironian sign in regards to the "normal" one in Lat7499. This can a) help determine the degree of tironian signs used as glosses, 2) which lemmas were glossed with tironian signs (is there something that unites them, are there the easiest to shorthand?) 3) determine a degree of material that would appeal to someone familiar with shorthand

# %%
tironian_Bamberg_Lat7499 = merged_df_Bamberg_Lat7499[['lemma_id', 'lemma_Bamberg', 'gloss_Bamberg', 'nature', 'lemma_Lat7499', 'gloss_Lat7499']]
tironian_Bamberg_Lat7499 = tironian_Bamberg_Lat7499[tironian_Bamberg_Lat7499['nature'] == 'shorthand']
tironian_Bamberg_Lat7499 = tironian_Bamberg_Lat7499.dropna()
tironian_Bamberg_Lat7499.to_csv('Bamberg_Lat7499_tironian_glosses.csv')

# %%
shorthand_rows = Bamberg[Bamberg['nature'] == 'shorthand']

# Count the number of 'shorthand' rows
shorthand_count = len(shorthand_rows)

# Count the total number of rows in the merged DataFrame
total_count = len(merged_df_Bamberg_Lat7499)

tironian_count = len(tironian_Bamberg_Lat7499)

# Calculate the percentage
percentage = (tironian_count / total_count) * 100

# Print the results
print(f"Number of 'shorthand' glosses not used for in-common-glossing with Lat7499: {shorthand_count}")
print(f"Total number of rows of shared lemmas between Bamberg and Lat7499:  {total_count}, out of which :")
print(f"Number of 'tironian' rows in the common Bamberg-Lat7499 dataframe: {tironian_count}")
print(f"Percentage of 'tironian' rows: {percentage:.2f}%")
# Out:
# Number of 'shorthand' glosses not used for in-common-glossing with Lat7499: 265
# Total number of rows of shared lemmas between Bamberg and Lat7499:  1103, out of which :
# Number of 'tironian' rows in the common Bamberg-Lat7499 dataframe: 148
# Percentage of 'tironian' rows: 13.42%

# %%
merged_df_Bamberg_Lat7499
# Out:
#      folio_Bamberg         lemma_id lemma_Bamberg gloss_id_Bamberg  \
# 0              71r     p447_l01_o00      EVTICII               NaN
# 1              71r     p447_l05_o02       SEMPER    p447_l05_o02_a
# 2              71r     p447_l05_o04   QVĘSTIONES    p447_l05_o04_a
# 3              71r     p447_l05_o05   DOCTORIBVS    p447_l05_o05_a
# 4              71r     p447_l05_o06    AVDITORVM    p447_l05_o06_a
# ...            ...              ...           ...              ...
# 1098           83r  p482_l11_o01-02     in .ror.               NaN
# 1099           83r  p482_l14_o01-02      in .so.               NaN
# 1100           83v     p483_l20_o04       Exulto    p483_l20_o04_a
# 1101           84r  p485_l20_o04-05     in .xor.               NaN
# 1102           84v     p486_l28_o07        motus    p486_l28_o07_a
#
#              gloss_Bamberg gloss_type_Bamberg gloss_form_Bamberg     nature  \
# 0                      NaN                NaN                NaN        NaN
# 1                   ꝓ sepe                S22                 F2     normal
# 2             ꝓ positiones                S22                 F2     normal
# 3     PRAECEP ͭ ͦ ͬ ͥᵇ ͧ ᷤ                S22                 F2  shorthand
# 4             discipulorũ                S22                 F2     normal
# ...                    ...                ...                ...        ...
# 1098                   NaN                NaN                NaN        NaN
# 1099                   NaN                NaN                NaN        NaN
# 1100                  l&or                S22                 F2     normal
# 1101                   NaN                NaN                NaN        NaN
# 1102                     +                S22                 F2     normal
#
#      marginal_note_id_Bamberg marginal_note_type_Bamberg  \
# 0              p447_l01_o00_a                        S54
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ...                       ...                        ...
# 1098        p482_l11_o01-02_a                        S63
# 1099        p482_l14_o01-02_a                        S63
# 1100                      NaN                        NaN
# 1101        p485_l20_o04-05_a                        S63
# 1102                      NaN                        NaN
#
#      marginal_note_form_Bamberg folio_Lat7499  \
# 0                            F5           73r
# 1                           NaN           73r
# 2                           NaN           73r
# 3                           NaN           73r
# 4                           NaN           73r
# ...                         ...           ...
# 1098                         F3           89v
# 1099                         F3           89v
# 1100                        NaN           90r
# 1101                         F2           90v
# 1102                        NaN           91r
#
#                                   lemma_Lat7499 gloss_id_Lat7499  \
# 0                                      EVTICII    p447_l01_o00_a
# 1                                       SEMPER    p447_l05_o02_a
# 2                                   QVESTIONES    p447_l05_o04_a
# 3                                    DOCTORIB    p447_l05_o05_a
# 4                                    AVDITORṼ    p447_l05_o06_a
# ...                                         ...              ...
# 1098                                  in .ror.               NaN
# 1099                                   In .so.               NaN
# 1100                                   exultat    p483_l20_o04_a
# 1101  \n                              In .xor.               NaN
# 1102                                    motus.    p486_l28_o07_a
#
#                             gloss_Lat7499 gloss_type_Lat7499  \
# 0     Eutex euticis. Inde euticius eutici                S54
# 1                                  ꝓ sepe                S22
# 2                           ÷ ꝓpositiones                S22
# 3                   magistris p̃ceptorib                S22
# 4                              discipuloꝵ                S22
# ...                                   ...                ...
# 1098                                  NaN                NaN
# 1099                                  NaN                NaN
# 1100                                    s               S611
# 1101                                  NaN                NaN
# 1102                             ł meatus                S22
#
#      gloss_form_Lat7499 marginal_note_id_Lat7499 marginal_note_type_Lat7499  \
# 0                    F3                      NaN                        NaN
# 1                    F2           p447_l05_o02_b                        S23
# 2                    F2           p447_l05_o04_b                       S631
# 3                    F3                      NaN                        NaN
# 4                    F2                      NaN                        NaN
# ...                 ...                      ...                        ...
# 1098                NaN        p482_l14_o01-02_a                        S63
# 1099                NaN                      NaN                        NaN
# 1100                 F1                      NaN                        NaN
# 1101                NaN        p485_l20_o04-05_a                        S63
# 1102                 F2                      NaN                        NaN
#
#      marginal_note_form_Lat7499
# 0                           NaN
# 1                            F5
# 2                            F5
# 3                           NaN
# 4                           NaN
# ...                         ...
# 1098                         F1
# 1099                        NaN
# 1100                        NaN
# 1101                         F3
# 1102                        NaN
#
# [1103 rows x 20 columns]

# %% [markdown]
# ### How many identical lemmas do they share?

# %%
# Filter the rows where the conditions are met
common_Bamberg_Lat7499 = merged_df_Bamberg_Lat7499[
    (merged_df_Bamberg_Lat7499['gloss_type_Bamberg'] == merged_df_Bamberg_Lat7499['gloss_type_Lat7499']) &
    ((merged_df_Bamberg_Lat7499['gloss_form_Bamberg'] == merged_df_Bamberg_Lat7499['gloss_form_Lat7499']) |
    (merged_df_Bamberg_Lat7499['marginal_note_type_Bamberg'] == merged_df_Bamberg_Lat7499['marginal_note_type_Lat7499']))
]

# Select the desired columns
common_Bamberg_Lat7499 = common_Bamberg_Lat7499[['lemma_id', 'gloss_type_Bamberg', 'gloss_type_Lat7499',
                                             'gloss_form_Bamberg', 'gloss_form_Lat7499']]

# Merge with merged_df_Bamberg_Lat7499 to get 'lemma_Bamberg' and 'lemma_Lat7499'
common_Bamberg_Lat7499 = common_Bamberg_Lat7499.merge(merged_df_Bamberg_Lat7499[['lemma_id', 'lemma_Bamberg', 'gloss_Bamberg', 'lemma_Lat7499', 'gloss_Lat7499']],
                                                  on='lemma_id', how='left')

# Save the result as a CSV file
common_Bamberg_Lat7499.to_csv('identical_glosses_csv/identical_glosses_Bamberg_Lat7499.csv', index=False)

# Display the new DataFrame
common_Bamberg_Lat7499
# Out:
#          lemma_id gloss_type_Bamberg gloss_type_Lat7499 gloss_form_Bamberg  \
# 0    p447_l05_o02                S22                S22                 F2
# 1    p447_l05_o04                S22                S22                 F2
# 2    p447_l05_o06                S22                S22                 F2
# 3    p447_l05_o07                S22                S22                 F3
# 4    p447_l07_o01                S22                S22                 F2
# ..            ...                ...                ...                ...
# 509  p472_l09_o01                S22                S22                 F2
# 510  p473_l01_o01                S22                S22                 F2
# 511  p474_l18_o08                S22                S22                 F2
# 512  p474_l19_o04                S22                S22                 F2
# 513  p486_l28_o07                S22                S22                 F2
#
#     gloss_form_Lat7499 lemma_Bamberg  \
# 0                   F2       SEMPER
# 1                   F2   QVĘSTIONES
# 2                   F2    AVDITORVM
# 3                   F3     ACVTIora
# 4                   F2     desider&
# ..                 ...           ...
# 509                 F2        cedt̃
# 510                 F2     Secundus
# 511                 F2           no
# 512                 F2          for
# 513                 F2        motus
#
#                                          gloss_Bamberg lemma_Lat7499  \
# 0                                               ꝓ sepe       SEMPER
# 1                                         ꝓ positiones   QVESTIONES
# 2                                         discipulorũ    AVDITORṼ
# 3    peritiora astutiora /subtiliora VALᵈ ͤ <...?>/...     acutiora
# 4                                           c̃cupiscat    desideret
# ..                                                 ...           ...
# 509                                          uerberare       cędunt
# 510                                              prosꝑ       Secunđ
# 511                                               nato           no
# 512                                             loquor          for
# 513                                                  +       motus.
#
#                                          gloss_Lat7499
# 0                                               ꝓ sepe
# 1                                        ÷ ꝓpositiones
# 2                                           discipuloꝵ
# 3    efficatiora ÷ ualde acuta, peritiora acutiora ...
# 4                                           .s. audire
# ..                                                 ...
# 509                                          uerberant
# 510                                              ÷ ꝓsꝑ
# 511                                               nato
# 512                                             loquor
# 513                                           ł meatus
#
# [514 rows x 9 columns]

# %%
merged_df_Bamberg_Lat7499['page'] = merged_df_Bamberg_Lat7499['lemma_id'].str.extract(r'(p\d+)')
subset_BambergLat7499 = merged_df_Bamberg_Lat7499[['page','lemma_id', 'gloss_form_Lat7499', 'gloss_form_Bamberg']]
subset_BambergLat7499 = subset_BambergLat7499.dropna()
#subset_BambergLat7499

# Convert F1-5 to numerical values 1-5
subset_BambergLat7499['gloss_form_Bamberg'] = subset_BambergLat7499['gloss_form_Bamberg'].str.extract('(\d)').astype(int)
subset_BambergLat7499['gloss_form_Lat7499'] = subset_BambergLat7499['gloss_form_Lat7499'].str.extract('(\d)').astype(int)

# Calculate the stability, increase, and decrease ratios
stable_ratio = (subset_BambergLat7499['gloss_form_Bamberg'] == subset_BambergLat7499['gloss_form_Lat7499']).mean()
increase_ratio = (subset_BambergLat7499['gloss_form_Bamberg'] < subset_BambergLat7499['gloss_form_Lat7499']).mean()
decrease_ratio = (subset_BambergLat7499['gloss_form_Bamberg'] > subset_BambergLat7499['gloss_form_Lat7499']).mean()

# Print the ratios
print("Stable Ratio: {:.2%}".format(stable_ratio))
print("Increase Ratio: {:.2%}".format(increase_ratio))
print("Decrease Ratio: {:.2%}".format(decrease_ratio))
# Out:
# Stable Ratio: 56.98%
# Increase Ratio: 36.09%
# Decrease Ratio: 6.93%

# %% [markdown]
# ### More can be done, but let's move to the next one

# %%
merged_df_Bamberg_Lat14087 = pd.merge(Bamberg, Lat14087, on='lemma_id', suffixes=('_Bamberg', '_Lat14087'))
merged_df_Bamberg_Lat14087
# Out:
#     folio      lemma_id        lemma        gloss_id  \
# 0     71r  p447_l05_o05  DOCTORIBVS   p447_l05_o05_a
# 1     71r  p447_l05_o06   AVDITORVM   p447_l05_o06_a
# 2     71r  p447_l18_o05   barutonos   p447_l18_o05_a
# 3     71r  p448_l02_o08   ꝑispomene   p448_l02_o08_a
# 4     71r  p448_l20_o07       sodes   p448_l20_o07_a
# ..    ...           ...          ...             ...
# 160   80r  p471_l06_o01    delapido   p471_l06_o01_a
# 161   80r  p471_l17_o02        Rodo   p471_l17_o02_a
# 162   82v  p480_l15_o11     aucupor   p480_l15_o11_a
# 163   83r  p481_l09_o03      lacero   p481_l09_o03_a
# 164   84r  p485_l13_o03        uexo   p485_l13_o03_a
#
#                                          gloss_Bamberg gloss_type_Bamberg  \
# 0                                 PRAECEP ͭ ͦ ͬ ͥᵇ ͧ ᷤ                S22
# 1                                         discipulorũ                S22
# 2    bari apud g̃cos dr̃ grauis tonos accentꝰ inde/...               S211
# 3    peri DIC ͥ ͭ ͧ ͬ circũ UNDE perispomene IDEST...               S211
# 4                                             si audes                S25
# ..                                                 ...                ...
# 160                                           defraudo                S22
# 161                                             deuoro                S22
# 162                                uenare ł aues capio                S23
# 163                                              lanio                S22
# 164                                             fatigo                S22
#
#     gloss_form_Bamberg     nature marginal_note_id marginal_note_type  \
# 0                   F2  shorthand              NaN                NaN
# 1                   F2     normal              NaN                NaN
# 2                   F4     normal              NaN                NaN
# 3                   F4     normal              NaN                NaN
# 4                   F3     normal              NaN                NaN
# ..                 ...        ...              ...                ...
# 160                 F2     normal   p471_l06_o01_b                S63
# 161                 F2     normal              NaN                NaN
# 162                 F4     normal   p480_l15_o11_b                S63
# 163                 F2     normal              NaN                NaN
# 164                 F2     normal              NaN                NaN
#
#     marginal_note_form                                     gloss_Lat14087  \
# 0                  NaN                       Preceptor. doctor ł magifter
# 1                  NaN                               Adiutor/ discipulus
# 2                  NaN                            Barithonos/Aliena atona
# 3                  NaN                      Perspomene. quasi circũ flexo
# 4                  NaN                                           si audes
# ..                 ...                                                ...
# 160                 F2  Delapido Erogo ꝓdico  ꝑdo exhaurio consumo sup...
# 161                NaN                                      Rodo mordeo
# 162                 F3          Aucupor affecto. lnsdior Adipiscor conor.
# 163                NaN                                   lacero ł iterimo
# 164                NaN                             Vexo Mulco uł affligo.
#
#     gloss_type_Lat14087 gloss_form_Lat14087
# 0                   S22                  F3
# 1                   S23                  F2
# 2                   S23                  F3
# 3                  S211                  F3
# 4                   S25                  F3
# ..                  ...                 ...
# 160                 S22                  F3
# 161                 S22                  F2
# 162                 S22                  F3
# 163                 S22                  F2
# 164                 S22                  F3
#
# [165 rows x 14 columns]

# %%
# Filter the rows where the conditions are met
common_Bamberg_Lat14087 = merged_df_Bamberg_Lat14087[
    (merged_df_Bamberg_Lat14087['gloss_type_Bamberg'] == merged_df_Bamberg_Lat14087['gloss_type_Lat14087']) &
    ((merged_df_Bamberg_Lat14087['gloss_form_Bamberg'] == merged_df_Bamberg_Lat14087['gloss_form_Lat14087']) )
]

# Select the desired columns
common_Bamberg_Lat14087 = common_Bamberg_Lat14087[['lemma_id', 'gloss_type_Bamberg', 'gloss_type_Lat14087',
                                             'gloss_form_Bamberg', 'gloss_form_Lat14087']]

# Merge with merged_df_Bamberg_Lat7499 to get 'lemma_Bamberg' and 'lemma_Lat7499'
common_Bamberg_Lat14087 = common_Bamberg_Lat14087.merge(merged_df_Bamberg_Lat14087[['lemma_id', 'lemma', 'gloss_Bamberg', 'gloss_Lat14087']],
                                                  on='lemma_id', how='left')

# Save the result as a CSV file
common_Bamberg_Lat14087.to_csv('identical_glosses_csv/identical_glosses_Bamberg_Lat14087.csv', index=False)

# Display the new DataFrame
common_Bamberg_Lat14087
# Out:
#         lemma_id gloss_type_Bamberg gloss_type_Lat14087 gloss_form_Bamberg  \
# 0   p448_l20_o07                S25                 S25                 F3
# 1   p450_l02_o04                S22                 S22                 F2
# 2   p450_l06_o07                S22                 S22                 F2
# 3   p450_l20_o04                S22                 S22                 F2
# 4   p451_l10_o02                S23                 S23                 F4
# 5   p451_l12_o02                S22                 S22                 F2
# 6   p451_l12_o03                S22                 S22                 F2
# 7   p451_l12_o07                S22                 S22                 F2
# 8   p451_l23_o05                S22                 S22                 F2
# 9   p452_l21_o01                S22                 S22                 F2
# 10  p452_l24_o07                S22                 S22                 F2
# 11  p453_l27_o03                S23                 S23                 F3
# 12  p453_l29_o02                S23                 S23                 F3
# 13  p453_l29_o08                S22                 S22                 F3
# 14  p454_l03_o04                S22                 S22                 F2
# 15  p454_l22_o01                S22                 S22                 F2
# 16  p455_l10_o05                S23                 S23                 F3
# 17  p455_l30_o02                S22                 S22                 F2
# 18  p456_l18_o07                S22                 S22                 F2
# 19  p457_l21_o10                S22                 S22                 F3
# 20  p457_l22_o05                S23                 S23                 F3
# 21  p457_l26_o07                S22                 S22                 F3
# 22  p457_l30_o06                S22                 S22                 F3
# 23  p457_l34_o05                S22                 S22                 F2
# 24  p457_l35_o10                S22                 S22                 F2
# 25  p458_l03_o06                S22                 S22                 F2
# 26  p458_l06_o07                S22                 S22                 F3
# 27  p458_l18_o05                S22                 S22                 F2
# 28  p458_l21_o06                S22                 S22                 F2
# 29  p458_l27_o05                S22                 S22                 F3
# 30  p458_l29_o09                S22                 S22                 F2
# 31  p459_l04_o07                S22                 S22                 F2
# 32  p459_l14_o03                S54                 S54                 F3
# 33  p459_l14_o04                S54                 S54                 F3
# 34  p459_l14_o05                S54                 S54                 F3
# 35  p459_l14_o06                S54                 S54                 F3
# 36  p459_l32_o11                S22                 S22                 F3
# 37  p462_l06_o07                S22                 S22                 F2
# 38  p462_l10_o02                S22                 S22                 F2
# 39  p463_l18_o10                S23                 S23                 F3
# 40  p463_l25_o02                S22                 S22                 F2
# 41  p463_l25_o03                S22                 S22                 F2
# 42  p465_l23_o02                S22                 S22                 F2
# 43  p465_l25_o11                S22                 S22                 F2
# 44  p465_l28_o08                S22                 S22                 F2
# 45  p466_l21_o09                S23                 S23                 F4
# 46  p471_l17_o02                S22                 S22                 F2
# 47  p481_l09_o03                S22                 S22                 F2
#
#    gloss_form_Lat14087       lemma                  gloss_Bamberg  \
# 0                   F3      sodes                        si audes
# 1                   F2    enucleo                       manifesto
# 2                   F2      fatuo                           hębeo
# 3                   F2    delinio                        blandior
# 4                   F4   pręsagio                   futura p̃dico
# 5                   F2      sopio                          dormio
# 6                   F2      ferio                          ꝑcutio
# 7                   F2   ligurrio                           lingo
# 8                   F2     potior                           fruor
# 9                   F2   Obsequor                       obtẽpero
# 10                  F2    ferculũ                          discus
# 11                  F3     strues      c̃genies t̃rę aug? cumulus
# 12                  F3    nubilis      puella apta (ad nubendum?)
# 13                  F3  effutilis                 uanus instab̶is
# 14                  F2      fallo                      (mentior?)
# 15                  F2       Cubo                           iaceo
# 16                  F3     compos                    adeptor uoti
# 17                  F2     Fultor                     sustentator
# 18                  F2    Censura                        iudiciũ
# 19                  F3      Multa              census ł̃ tributũ
# 20                  F3       Lixa   seruus militũ s. mercenarius
# 21                  F3     probus                         bonus +
# 22                  F3     Serenꝰ             tranquillus ł mitis
# 23                  F2       Apto                       accõmodo
# 24                  F2      uiduo                               +
# 25                  F2     T̃minꝰ                           finis
# 26                  F3       libo               sacrifico/p̃gusto
# 27                  F2  deuirgino                               +
# 28                  F2    exubero                          abundo
# 29                  F3       sedo                    mitigo/placo
# 30                  F2   detestor                        abominor
# 31                  F2     Pernox                          ꝑuigil
# 32                  F3      acies               exercitꝰ / a acuo
# 33                  F3     Facies               credulitas/a fido
# 34                  F3      Fides                        ̃a facio
# 35                  F3        Res                a VERB ͧ ͫ  reor
# 36                  F3    indagor             inuestigo ł exploro
# 37                  F2      uello                           carpo
# 38                  F2    sarcino                         pondero
# 39                  F3       calx            extrema (pars pedis)
# 40                  F2        m&a                           finis
# 41                  F2       M&or                            figo
# 42                  F2  ludificor                               +
# 43                  F2  polliceor                         spondeo
# 44                  F2   blandior                          adulor
# 45                  F4   Paciscor                     pacẽ facio
# 46                  F2       Rodo                          deuoro
# 47                  F2     lacero                           lanio
#
#                                        gloss_Lat14087
# 0                                            si audes
# 1                                      Nucleo. claudo
# 2                                      fatuor hebesco
# 3                                   Delinior blandior
# 4   P̃dico. cis. futura. antedico . P̃dico cas; de...
# 5                                        Sopio Dormio
# 6                                     Exsicco ł ferio
# 7                                   Ligurrio deglutio
# 8                                        Potior fruor
# 9                                    Obsequor famulor
# 10                                     ferculũ discus
# 11                            c̃geries cuiꝰ lib& regi
# 12                         Nubilis ad nubendũ habilis
# 13    Effutilis inutilis ł in stablis uanꝰ ł loquax;
# 14                                   decipio frustror
# 15                                     Cubo reqͥesco.
# 16                 Cõpos possessor ł assecutor uoti;
# 17                                 Flutor sustentator
# 18            Censura decus. seueritas. honor iuditia
# 19                        Multa occisio. ł int̃emptio
# 20                                   Lixa aqua lipida
# 21  ꝓbus. benemoratꝰ. honestus. Festiuus decens . ...
# 22            Serenus. purus. tranquillus . placidus.
# 23                              Apto. c̃iungo ł sotio
# 24                                     Viduo. desclor
# 25                                         M&a finis
# 26                      libo sacrifico. uel deglisto.
# 27                        Deuirgino corrũpo. c̃tamino
# 28                                    Exuberor abundo
# 29  Sedo. Mollio placo. Mitigo // Sedo. pacifico. ...
# 30                                  Detestor abominor
# 31                                         ꝑnox ꝑuigl
# 32                                     Acies. ab acuo
# 33                                     facies a fatio
# 34                                      fides a  fido
# 35                                         Res a reor
# 36                        indagor. Inuestigo. inquiro
# 37                                        Vello moueo
# 38                                    sarcinor oneror
# 39                          calx posterior pars pedis
# 40                                          M&a finis
# 41                                      termino finio
# 42                                   ludifico. eludo
# 43                                 ꝓmitto polliceor.
# 44                                   Blandior. placeo
# 45                         Pasciscor pacẽ redintegror
# 46                                      Rodo mordeo
# 47                                   lacero ł iterimo

# %%
merged_df_Bamberg_Lat14087['page'] = merged_df_Bamberg_Lat14087['lemma_id'].str.extract(r'(p\d+)')
subset_Bamberg_Lat14087 = merged_df_Bamberg_Lat14087[['page','lemma_id', 'gloss_form_Bamberg', 'gloss_form_Lat14087']]
subset_Bamberg_Lat14087 = subset_Bamberg_Lat14087.dropna()
# Calculate the stability, increase, and decrease ratios
stable_ratio = (subset_Bamberg_Lat14087['gloss_form_Bamberg'] == subset_Bamberg_Lat14087['gloss_form_Lat14087']).mean()
increase_ratio = (subset_Bamberg_Lat14087['gloss_form_Bamberg'] < subset_Bamberg_Lat14087['gloss_form_Lat14087']).mean()
decrease_ratio = (subset_Bamberg_Lat14087['gloss_form_Bamberg'] > subset_Bamberg_Lat14087['gloss_form_Lat14087']).mean()

# Print the ratios
print("Stable Ratio: {:.2%}".format(stable_ratio))
print("Increase Ratio: {:.2%}".format(increase_ratio))
print("Decrease Ratio: {:.2%}".format(decrease_ratio))
# Out:
# Stable Ratio: 36.94%
# Increase Ratio: 52.23%
# Decrease Ratio: 10.83%

# %% [markdown]
# ### More can be done, but let's move to the next one

# %%
merged_df_Lat14087_Lat7499 = pd.merge(Lat14087, Lat7499, on='lemma_id', suffixes=('_Lat14087', '_Lat7499'))
merged_df_Lat14087_Lat7499
# Out:
#          lemma_id                                     gloss_Lat14087  \
# 0    p447_l05_o05                       Preceptor. doctor ł magifter
# 1    p447_l05_o06                               Adiutor/ discipulus
# 2    p447_l18_o05                            Barithonos/Aliena atona
# 3    p448_l02_o08                      Perspomene. quasi circũ flexo
# 4    p448_l20_o07                                           si audes
# ..            ...                                                ...
# 163  p466_l21_o09                         Pasciscor pacẽ redintegror
# 164  p466_l22_o02    Adipiscor conor / Nasiciscor Adipiscor Assequor
# 165  p467_l07_o05                                   Neo filator queo
# 166  p468_l34_o08                edico cis p̃dico p̃nuntio ł p̃cipio
# 167  p468_l34_o10  P̃dico. cis. futura. antedico . P̃dico cas; de...
#
#     gloss_type_Lat14087 gloss_form_Lat14087 folio         lemma  \
# 0                   S22                  F3   73r    DOCTORIB
# 1                   S23                  F2   73r    AVDITORṼ
# 2                   S23                  F3   73r     ΒΑΡΙΤΟΝΑ
# 3                  S211                  F3   73r  ΠΕΡΙCΠΩΜΕΝΗ
# 4                   S25                  F3   73v        Sodes
# ..                  ...                 ...   ...           ...
# 163                 S23                  F4   84v      pacisor
# 164                 S22                  F3   84v   Adipiscor;
# 165                 S22                  F3   84v          neo
# 166                 S22                  F3   85v        Edico
# 167                 S23                  F4   85v      Predico
#
#            gloss_id                                      gloss_Lat7499  \
# 0    p447_l05_o05_a                              magistris p̃ceptorib
# 1    p447_l05_o06_a                                         discipuloꝵ
# 2    p447_l18_o05_a                                          grauisona
# 3    p448_l02_o08_a  cirũflexibils; ΠΕΡΙCΠΩ ÷ circũfleto/ΠΕΡΙ dr̃ c...
# 4    p448_l20_o07_a                                           si audes
# ..              ...                                                ...
# 163  p466_l21_o09_a                                        pacẽ fatio
# 164  p466_l22_o02_a                                  consequor inuenio
# 165  p467_l07_o05_a                                               filo
# 166  p468_l34_o08_a                                         ualde dico
# 167  p468_l34_o10_a                                           antedico
#
#     gloss_type_Lat7499 gloss_form_Lat7499 marginal_note_id marginal_note_type  \
# 0                  S22                 F3              NaN                NaN
# 1                  S22                 F2              NaN                NaN
# 2                 S211                 F2              NaN                NaN
# 3                 S211                 F4              NaN                NaN
# 4                  S25                 F3              NaN                NaN
# ..                 ...                ...              ...                ...
# 163                S23                 F4              NaN                NaN
# 164                S22                 F3              NaN                NaN
# 165                S22                 F2              NaN                NaN
# 166                S23                 F4              NaN                NaN
# 167                S22                 F2              NaN                NaN
#
#     marginal_note_form
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 163                NaN
# 164                NaN
# 165                NaN
# 166                NaN
# 167                NaN
#
# [168 rows x 13 columns]

# %%
# Filter the rows where the conditions are met
common_Lat14087_Lat7499 = merged_df_Lat14087_Lat7499[
    (merged_df_Lat14087_Lat7499['gloss_type_Lat14087'] == merged_df_Lat14087_Lat7499['gloss_type_Lat7499']) &
    ((merged_df_Lat14087_Lat7499['gloss_form_Lat14087'] == merged_df_Lat14087_Lat7499['gloss_form_Lat7499']) )
]

common_Lat14087_Lat7499

# Select the desired columns
common_Lat14087_Lat7499 = common_Lat14087_Lat7499[['lemma_id', 'gloss_type_Lat14087', 'gloss_type_Lat7499',
                                             'gloss_form_Lat14087', 'gloss_form_Lat7499']]


# Merge with merged_df_Bamberg_Lat7499 to get 'lemma_Bamberg' and 'lemma_Lat7499'
common_Lat14087_Lat7499 = common_Lat14087_Lat7499.merge(merged_df_Lat14087_Lat7499[['lemma_id', 'lemma', 'gloss_Lat14087', 'gloss_Lat7499']],
                                                  on='lemma_id', how='left')

# Save the result as a CSV file
common_Lat14087_Lat7499.to_csv('identical_glosses_csv/identical_glosses_Lat14087Lat7499.csv', index=False)

# Display the new DataFrame
common_Lat14087_Lat7499
# Out:
#         lemma_id gloss_type_Lat14087 gloss_type_Lat7499 gloss_form_Lat14087  \
# 0   p447_l05_o05                 S22                S22                  F3
# 1   p448_l20_o07                 S25                S25                  F3
# 2   p449_l12_o03                S553               S553                  F3
# 3   p450_l02_o01                 S22                S22                  F3
# 4   p450_l20_o04                 S22                S22                  F2
# 5   p450_l22_o07                 S23                S23                  F3
# 6   p451_l12_o03                 S22                S22                  F2
# 7   p451_l13_o03                 S22                S22                  F2
# 8   p451_l23_o05                 S22                S22                  F2
# 9   p452_l18_o07                 S22                S22                  F3
# 10  p453_l27_o03                 S23                S23                  F3
# 11  p453_l29_o08                 S22                S22                  F3
# 12  p453_l29_o02                 S23                S23                  F3
# 13  p453_l30_o04                 S22                S22                  F3
# 14  p454_l03_o04                 S22                S22                  F2
# 15  p454_l17_o07                 S23                S23                  F4
# 16  p454_l22_o01                 S22                S22                  F2
# 17  p455_l10_o05                 S23                S23                  F3
# 18  p457_l18_o02                 S22                S22                  F3
# 19  p457_l18_o03                 S22                S22                  F3
# 20  p457_l18_o05                 S22                S22                  F3
# 21  p457_l21_o07                 S22                S22                  F2
# 22  p457_l21_o10                 S22                S22                  F3
# 23  p457_l21_o11                 S22                S22                  F3
# 24  p457_l26_o07                 S22                S22                  F3
# 25  p457_l30_o06                 S22                S22                  F3
# 26  p457_l34_o08                 S22                S22                  F3
# 27  p458_l02_o10                 S22                S22                  F3
# 28  p458_l11_o11                 S22                S22                  F3
# 29  p458_l21_o06                 S22                S22                  F2
# 30  p458_l21_o09                 S22                S22                  F3
# 31  p458_l25_o06                 S22                S22                  F3
# 32  p458_l27_o05                 S22                S22                  F3
# 33  p459_l04_o07                 S22                S22                  F2
# 34  p459_l13_o03                 S22                S22                  F3
# 35  p459_l14_o04                 S54                S54                  F3
# 36  p459_l14_o05                 S54                S54                  F3
# 37  p459_l14_o06                 S54                S54                  F3
# 38  p459_l32_o11                 S22                S22                  F3
# 39  p461_l20_o02                 S23                S23                  F4
# 40  p462_l10_o02                 S22                S22                  F2
# 41  p463_l08_o06                 S23                S23                  F4
# 42  p463_l15_o06                 S22                S22                  F3
# 43  p465_l29_o03                 S22                S22                  F3
# 44  p466_l21_o09                 S23                S23                  F4
# 45  p466_l22_o02                 S22                S22                  F3
#
#    gloss_form_Lat7499        lemma  \
# 0                  F3   DOCTORIB
# 1                  F3       Sodes
# 2                  F3    protheus
# 3                  F3         Meo
# 4                  F2     Delinio
# 5                  F3    Depretio
# 6                  F2       Ferio
# 7                  F2      Haurio
# 8                  F2      potior
# 9                  F3    Pręsideo
# 10                 F3      Strues
# 11                 F3     effutił
# 12                 F3       nubił
# 13                 F3     Pręcido
# 14                 F2       Fallo
# 15                 F4       ꝓnuba
# 16                 F2        Cubo
# 17                 F3      cõpos.
# 18                 F3     Trutina
# 19                 F3     Trutino
# 20                 F3     Machina
# 21                 F2        Rota
# 22                 F3       Multa
# 23                 F3       Multo
# 24                 F3        ꝓbus
# 25                 F3     Serenus
# 26                 F3   Sollicito
# 27                 F3     Stimulo
# 28                 F3       ꝑagro
# 29                 F2     Exubero
# 30                 F3      Aggero
# 31                 F3       Nugas
# 32                 F3        Sedo
# 33                 F2        ꝑnox
# 34                 F3       nisus
# 35                 F3      Facies
# 36                 F3       Fides
# 37                 F3         Res
# 38                 F3     iNdagor
# 39                 F4   coꝑendino
# 40                 F2    sarcinor
# 41                 F4       bulla
# 42                 F3       Sepio
# 43                 F3     Operior
# 44                 F4     pacisor
# 45                 F3  Adipiscor;
#
#                                        gloss_Lat14087  \
# 0                        Preceptor. doctor ł magifter
# 1                                            si audes
# 2                                 ꝓtheus pastor quidã
# 3                                 Defluo Decurro mano
# 4                                   Delinior blandior
# 5                                Deprecio / uilẽfacio
# 6                                     Exsicco ł ferio
# 7                                       Haurio.Euacuo
# 8                                        Potior fruor
# 9   P̃sideo ꝓtego subleuo opitulor. suffragor ł ꝓp...
# 10                            c̃geries cuiꝰ lib& regi
# 11    Effutilis inutilis ł in stablis uanꝰ ł loquax;
# 12                         Nubilis ad nubendũ habilis
# 13                             Cedo transigo conficio
# 14                                   decipio frustror
# 15     ꝓnuba. quę nubentibus p̃÷ łquae utrũq c̃iugit;
# 16                                     Cubo reqͥesco.
# 17                 Cõpos possessor ł assecutor uoti;
# 18                      Trutina pensa statera mensura
# 19                          Trutino. pondero ł ꝓpendo
# 20  Machinor molior exquiro. fabrico. paro c̃fitio...
# 21                                      gemino cresco
# 22                        Multa occisio. ł int̃emptio
# 23                    condẽpno uexo. lacero ł iterimo
# 24  ꝓbus. benemoratꝰ. honestus. Festiuus decens . ...
# 25            Serenus. purus. tranquillus . placidus.
# 26                     Sollicito. inquięto. molesto.
# 27                        Stimulo urgeo  fimo. Sordeo
# 28          ꝑagror circũeo ꝑãbo ꝑtranseo.giro. uagor
# 29                                    Exuberor abundo
# 30                          Aggeror. comulo. congrego
# 31    Nugas turpes. uanos. inutiles. uanos maculosos.
# 32  Sedo. Mollio placo. Mitigo // Sedo. pacifico. ...
# 33                                         ꝑnox ꝑuigl
# 34                               Nisus conam̃ cestam̃
# 35                                     facies a fatio
# 36                                      fides a  fido
# 37                                         Res a reor
# 38                        indagor. Inuestigo. inquiro
# 39           cõꝑendino. in t̃tiũ diẽ ꝓtraho ł differo
# 40                                    sarcinor oneror
# 41  Bulla inflatio auqarũ ł ornam̃ in similitudine...
# 42                               Sepior circũdo uallo
# 43                     Opperior expecto. cupio. spero
# 44                         Pasciscor pacẽ redintegror
# 45    Adipiscor conor / Nasiciscor Adipiscor Assequor
#
#                                         gloss_Lat7499
# 0                               magistris p̃ceptorib
# 1                                            si audes
# 2                                            ꝓpũ nom̃
# 3                                      transeo/ãbulo
# 4                                            blandior
# 5                                         uilẽ facio
# 6                                              ꝑcutio
# 7                                               ꝓpino
# 8                                            possideo
# 9                                antesedeo/seu pręsum
# 10                    congeries ligni/ł cumulus terrę
# 11                                  uanus/ instabilis
# 12                            puella/apta ad/nubendũ
# 13                                        ambulo/cedo
# 14                                             m̃tior
# 15                                  ꝗ nubentib p̃est
# 16                                              iaceo
# 17  effector uoti ł adeptor uoti/ł cõpositor orna...
# 18                                      lanx ł m̃sura
# 19                     ęqualit̃ m̃suro/pondero coęquo
# 20                                 argum̃tũ/ędificium
# 21                                        uolubilitas
# 22                           occisio censꝰ/ł tributum
# 23                              dãpno occido/condẽpno
# 24                                bonus ęquus/ꝑfectus
# 25                          humilis tranquillus/mitis
# 26                                       curo assiduo
# 27                                       pungo incito
# 28                            ꝑagro suado/seu ꝑlustro
# 29                                            habundo
# 30                                   c̃grego accumulo
# 31                               uanꝰ mał t᷑pis piger
# 32                        mitigo placo/sereno fecundo
# 33                                             ꝑuigil
# 34                       audeo A nitor Conam̃ conatio
# 35                                            a fatio
# 36                                 a ũbo fido ÷ credo
# 37                                         a ũbo Reor
# 38                            inꝗro exploro inuestigo
# 39       ÷ ꝓlongo differo in aliũ diem in longũ mitto
# 40                                            pondero
# 41           ornam̃tũ camelorũ si/ue uesicule in aqua
# 42                                      munio circũdo
# 43                                prestolor/ł expecto
# 44                                        pacẽ fatio
# 45                                  consequor inuenio

# %% [markdown]
# ### Let's omit the glossary for now and focus on the manuscripts. I'll put them in chronological order to track the evolution of the diffusion of annotations

# %%
merged_df_full = pd.merge(merged_df_VLO_Bamberg, Lat7499, on='lemma_id', suffixes=('','_Latin7499'))
merged_df_full.to_csv('full_comp_mss.csv', index=False)
merged_df_full
# Out:
#          lemma_id folio_VLO41                                   lemma_VLO41  \
# 0    p447_l01_o00         02r  INCIPIT LIBER EVTI/CI GRAMMAT(I)CI /DE VERBO
# 1    p447_l05_o02         02r                                        semper
# 2    p447_l05_o04         02r                             nouas quaestiones
# 3    p447_l05_o05         02r                                     doctorib;
# 4    p447_l05_o06         02r                                     auditorum
# ..            ...         ...                                           ...
# 492  p466_l06_o03         18v                                         rimor
# 493  p466_l21_o09         19r                                      paciscor
# 494  p466_l22_o02         19r                                     adipiscor
# 495  p470_l09_o07         21v                                        glisco
# 496  p471_l26_o01         22v                                         trudo
#
#               gloss_VLO41 gloss_type_VLO41 gloss_form_VLO41  \
# 0                     NaN              NaN              NaN
# 1       s. cũ frequentia              S23               F3
# 2    novẽ int̃rogaciones              S22               F3
# 3          p̃ce<ptoribus>              S22               F2
# 4         iđ discipulorũ              S22               F2
# ..                    ...              ...              ...
# 492              ꝑscrutor              S22               F2
# 493           pactũ facio              S23               F4
# 494            inueniscor              S22               F2
# 495                cresco              S22               F2
# 496              impello               S22               F2
#
#                       marginal_note_id_VLO41 marginal_note_type_VLO41  \
# 0    ++++/de uer[bo] ++++/[bo]nus contextor                      S523
# 1                                        NaN                      NaN
# 2                                        NaN                      NaN
# 3                                        NaN                      NaN
# 4                                        NaN                      NaN
# ..                                       ...                      ...
# 492                                      NaN                      NaN
# 493                                      NaN                      NaN
# 494                                      NaN                      NaN
# 495                                      NaN                      NaN
# 496                                      NaN                      NaN
#
#     marginal_note_form_VLO41 folio_Bamberg  ...  page folio        lemma  \
# 0                         F4           71r  ...  p447   73r     EVTICII
# 1                        NaN           71r  ...  p447   73r      SEMPER
# 2                        NaN           71r  ...  p447   73r  QVESTIONES
# 3                        NaN           71r  ...  p447   73r   DOCTORIB
# 4                        NaN           71r  ...  p447   73r   AVDITORṼ
# ..                       ...           ...  ...   ...   ...          ...
# 492                      NaN           78v  ...  p466   84v       Rimor
# 493                      NaN           78v  ...  p466   84v     pacisor
# 494                      NaN           78v  ...  p466   84v  Adipiscor;
# 495                      NaN           80r  ...  p470   85v      Glisco
# 496                      NaN           80r  ...  p471   86r       Trudo
#
#     gloss_id_Latin7499                                gloss gloss_type  \
# 0       p447_l01_o00_a  Eutex euticis. Inde euticius eutici        S54
# 1       p447_l05_o02_a                               ꝓ sepe        S22
# 2       p447_l05_o04_a                        ÷ ꝓpositiones        S22
# 3       p447_l05_o05_a                magistris p̃ceptorib        S22
# 4       p447_l05_o06_a                           discipuloꝵ        S22
# ..                 ...                                  ...        ...
# 492     p466_l06_o03_a                               inqͥro        S22
# 493     p466_l21_o09_a                          pacẽ fatio        S23
# 494     p466_l22_o02_a                    consequor inuenio        S22
# 495     p470_l09_o07_a                               cresco        S22
# 496     p471_l26_o01_a              includo impingo ł pello        S22
#
#     gloss_form marginal_note_id marginal_note_type marginal_note_form
# 0           F3              NaN                NaN                NaN
# 1           F2   p447_l05_o02_b                S23                 F5
# 2           F2   p447_l05_o04_b               S631                 F5
# 3           F3              NaN                NaN                NaN
# 4           F2              NaN                NaN                NaN
# ..         ...              ...                ...                ...
# 492         F2              NaN                NaN                NaN
# 493         F4              NaN                NaN                NaN
# 494         F3              NaN                NaN                NaN
# 495         F2              NaN                NaN                NaN
# 496         F3              NaN                NaN                NaN
#
# [497 rows x 29 columns]

# %% [markdown]
# ### Accumulation of synonyms

# %%
full_S22_form = merged_df_full[
    (merged_df_full['gloss_type_VLO41'] == 'S22') &
    (merged_df_full['gloss_type_Bamberg'] == 'S22') &
    (merged_df_full['gloss_type'] == 'S22')
][['lemma_id', 'gloss_VLO41', 'gloss_type_VLO41', 'gloss_form_VLO41', 'gloss_Bamberg', 'gloss_type_Bamberg', 'gloss_form_Bamberg', 'gloss', 'gloss_type', 'gloss_form']]

# %%
full_S22_form
# Out:
#          lemma_id            gloss_VLO41 gloss_type_VLO41 gloss_form_VLO41  \
# 2    p447_l05_o04   novẽ int̃rogaciones              S22               F3
# 3    p447_l05_o05         p̃ce<ptoribus>              S22               F2
# 4    p447_l05_o06        iđ discipulorũ              S22               F2
# 5    p447_l05_o07          perspicatiora              S22               F2
# 6    p447_l05_o08  reperire et excitare               S22               F3
# ..            ...                    ...              ...              ...
# 491  p466_l05_o06               auxilior              S22               F2
# 492  p466_l06_o03               ꝑscrutor              S22               F2
# 494  p466_l22_o02             inueniscor              S22               F2
# 495  p470_l09_o07                 cresco              S22               F2
# 496  p471_l26_o01               impello               S22               F2
#
#                                          gloss_Bamberg gloss_type_Bamberg  \
# 2                                         ꝓ positiones                S22
# 3                                 PRAECEP ͭ ͦ ͬ ͥᵇ ͧ ᷤ                S22
# 4                                         discipulorũ                S22
# 5    peritiora astutiora /subtiliora VALᵈ ͤ <...?>/...                S22
# 6                                             incitare                S22
# ..                                                 ...                ...
# 491                                           auxilior                S22
# 492                                          inuestigo                S22
# 494                                          consequor                S22
# 495                                             cresco                S22
# 496                                             indudo                S22
#
#     gloss_form_Bamberg                                              gloss  \
# 2                   F2                                      ÷ ꝓpositiones
# 3                   F2                              magistris p̃ceptorib
# 4                   F2                                         discipuloꝵ
# 5                   F3  efficatiora ÷ ualde acuta, peritiora acutiora ...
# 6                   F2                                 suscitare incitare
# ..                 ...                                                ...
# 491                 F2                             a suffragio ÷ auxilior
# 492                 F2                                             inqͥro
# 494                 F2                                  consequor inuenio
# 495                 F2                                             cresco
# 496                 F2                            includo impingo ł pello
#
#     gloss_type gloss_form
# 2          S22         F2
# 3          S22         F3
# 4          S22         F2
# 5          S22         F3
# 6          S22         F3
# ..         ...        ...
# 491        S22         F3
# 492        S22         F2
# 494        S22         F3
# 495        S22         F2
# 496        S22         F3
#
# [231 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

# Create masks for increasing, decreasing, and stable tendencies
increasing_mask = (
    ((full_S22_form['gloss_form_VLO41'] == 'F2') & (full_S22_form['gloss_form_Bamberg'] == 'F3') & (full_S22_form['gloss_form'] == 'F3')) |
    ((full_S22_form['gloss_form_VLO41'] == 'F2') & (full_S22_form['gloss_form_Bamberg'] == 'F2') & (full_S22_form['gloss_form'] != 'F3'))
)

decreasing_mask = (
    ((full_S22_form['gloss_form_VLO41'] == 'F3') & (full_S22_form['gloss_form_Bamberg'] == 'F2') & (full_S22_form['gloss_form'] == 'F2')) |
    ((full_S22_form['gloss_form_VLO41'] == 'F3') & (full_S22_form['gloss_form_Bamberg'] == 'F3') & (full_S22_form['gloss_form'] == 'F2'))
)

stable_mask = (
    ((full_S22_form['gloss_form_VLO41'] == 'F2') & (full_S22_form['gloss_form_Bamberg'] == 'F2') & (full_S22_form['gloss_form'] == 'F2')) |
    ((full_S22_form['gloss_form_VLO41'] == 'F3') & (full_S22_form['gloss_form_Bamberg'] == 'F3') & (full_S22_form['gloss_form'] == 'F3'))
)

# Apply the masks to filter the rows
increasing_cases = full_S22_form[increasing_mask]
decreasing_cases = full_S22_form[decreasing_mask]
stable_cases = full_S22_form[stable_mask]

# Get the counts of each tendency
increasing_count = len(increasing_cases)
decreasing_count = len(decreasing_cases)
stable_count = len(stable_cases)

# %%
decreasing_cases
# Out:
#          lemma_id                       gloss_VLO41 gloss_type_VLO41  \
# 2    p447_l05_o04              novẽ int̃rogaciones              S22
# 110  p450_l20_o04             lineã destro ł unguo              S22
# 111  p450_l20_o06              adiutoriũ [adiuta]?              S22
# 114  p450_l26_o01                       purgo/mundo              S22
# 125  p451_l10_o05                 constituo/c̃firmo              S22
# 128  p451_l11_o04                      orno/redimio              S22
# 199  p453_l10_o11  defitio areo tabesco siue macior              S22
# 212  p453_l19_o07                     tollo /aufero              S22
# 217  p453_l29_o04             leuis/qͣsi possibilis              S22
# 299  p455_l20_o01         cib; qualiscũq; /pabulũ              S22
# 300  p455_l20_o02                aum̃tũ increm̃tũ              S22
# 303  p455_l21_o01          res humida ◌͛ humida res              S22
# 332  p457_l10_o04               prudentia sagacitas              S22
# 410  p458_l31_o02                     uentus /honor              S22
# 411  p458_l31_o03                     orno /uenusto              S22
# 416  p459_l01_o06               dr̃ furtũ deceptio              S22
# 438  p459_l25_o02                  aperio manifesto              S22
# 445  p461_l10_o02                    luceo splendeo              S22
# 446  p461_l10_o04                  sepelio/cooperio              S22
# 477  p463_l15_o04                       decoro orno              S22
# 479  p463_l17_o02                      adꝗro exulto              S22
#
#     gloss_form_VLO41 gloss_Bamberg gloss_type_Bamberg gloss_form_Bamberg  \
# 2                 F3  ꝓ positiones                S22                 F2
# 110               F3      blandior                S22                 F2
# 111               F3      adium̃tũ                S22                 F2
# 114               F3         mundo                S22                 F2
# 125               F3       c̃firmo                S22                 F2
# 128               F3      nobilito                S22                 F2
# 199               F3          areo                S22                 F2
# 212               F3        aufero                S22                 F2
# 217               F3         leuis                S22                 F2
# 299               F3    nutrim̃tũ                S22                 F2
# 300               F3       augm̃tũ                S22                 F2
# 303               F3       ligatio                S22                 F2
# 332               F3     sagacitas                S22                 F2
# 410               F3         honor                S22                 F2
# 411               F3          orno                S22                 F2
# 416               F3      deceptio                S22                 F2
# 438               F3        aperio                S22                 F2
# 445               F3      splendeo                S22                 F2
# 446               F3        tellus                S22                 F2
# 477               F3       noblito                S22                 F2
# 479               F3      desidero                S22                 F2
#
#              gloss gloss_type gloss_form
# 2    ÷ ꝓpositiones        S22         F2
# 110       blandior        S22         F2
# 111       adium̃tũ        S22         F2
# 114          mundo        S22         F2
# 125        c̃firmo        S22         F2
# 128        nobilio        S22         F2
# 199           areo        S22         F2
# 212         aufero        S22         F2
# 217          leuis        S22         F2
# 299     Nutrimentũ        S22         F2
# 300       augm̃tũ        S22         F2
# 303        ligatio        S22         F2
# 332    sollicitudo        S22         F2
# 410          honor        S22         F2
# 411           orno        S22         F2
# 416       deceptio        S22         F2
# 438         aperio        S22         F2
# 445       splendeo        S22         F2
# 446         tellus        S22         F2
# 477       nobilito        S22         F2
# 479       desidero        S22         F2

# %%
import matplotlib.pyplot as plt

# Calculate the total count
total_count = decreasing_count + stable_count + increasing_count

# Calculate the percentages
decreasing_percentage = (decreasing_count / total_count) * 100
stable_percentage = (stable_count / total_count) * 100
increasing_percentage = (increasing_count / total_count) * 100

# Create a larger figure with a cute style
plt.figure(figsize=(8, 6))
plt.style.use('seaborn-pastel')

# Create a bar plot to visualize the counts
tendencies = ['Decreasing', 'Stable', 'Increasing']
counts = [decreasing_count, stable_count, increasing_count]
percentages = [decreasing_percentage, stable_percentage, increasing_percentage]
colors = ['#1B9E77', '#D95F02', '#7570B3']

plt.bar(tendencies, counts, color=colors)
plt.xlabel('Tendency')
plt.ylabel('Count')
plt.title('Percentage of tendencies across the S22 typology across VLO41-BambergMsc30-Lat7499')

# Add percentages on top of the bars
for i, count in enumerate(counts):
    plt.text(i, count + 5, f'{percentages[i]:.2f}%', ha='center')

plt.tight_layout()

plt.savefig('graphs/tendencies_S22_form_across_mss.png')

plt.show()
# Out:
# /var/folders/ps/09_p7rl14y11qx52mcmvrr_w0000gq/T/ipykernel_87005/3566706660.py:13: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-pastel')

# %%
merged_df_full_gloss_to_marginalia = merged_df_full [['lemma_id','marginal_note_id_VLO41','marginal_note_id_Bamberg','marginal_note_id']]
merged_df_full_gloss_to_marginalia
# Out:
#          lemma_id                   marginal_note_id_VLO41  \
# 0    p447_l01_o00  ++++/de uer[bo] ++++/[bo]nus contextor
# 1    p447_l05_o02                                      NaN
# 2    p447_l05_o04                                      NaN
# 3    p447_l05_o05                                      NaN
# 4    p447_l05_o06                                      NaN
# ..            ...                                      ...
# 492  p466_l06_o03                                      NaN
# 493  p466_l21_o09                                      NaN
# 494  p466_l22_o02                                      NaN
# 495  p470_l09_o07                                      NaN
# 496  p471_l26_o01                                      NaN
#
#     marginal_note_id_Bamberg marginal_note_id
# 0             p447_l01_o00_a              NaN
# 1                        NaN   p447_l05_o02_b
# 2                        NaN   p447_l05_o04_b
# 3                        NaN              NaN
# 4                        NaN              NaN
# ..                       ...              ...
# 492           p466_l06_o03_b              NaN
# 493                      NaN              NaN
# 494                      NaN              NaN
# 495           p470_l09_o07_b              NaN
# 496                      NaN              NaN
#
# [497 rows x 4 columns]

# %%
# Rows where gloss_VLO41 has None marginal_note_id_VLO41 and marginal_note_id_Bamberg is not None
condition_1 = (merged_df_full_gloss_to_marginalia['marginal_note_id_VLO41'].isna()) & (~merged_df_full_gloss_to_marginalia['marginal_note_id_Bamberg'].isna())
subset_1 = merged_df_full_gloss_to_marginalia[condition_1]

# Count of rows with None marginal_note_id_VLO41 and non-None marginal_note_id_Bamberg
count_1 = subset_1.shape[0]

condition_2 = (merged_df_full_gloss_to_marginalia['marginal_note_id_Bamberg'].isna()) & (~merged_df_full_gloss_to_marginalia['marginal_note_id'].isna())
subset_2 = merged_df_full_gloss_to_marginalia[condition_2]

count_2 = subset_2.shape[0]

# Rows where both marginal_note_id_VLO41 and marginal_note_id_Bamberg have None, and marginal_note_id is not None
condition_3 = (merged_df_full_gloss_to_marginalia['marginal_note_id_VLO41'].isna()) & (~merged_df_full_gloss_to_marginalia['marginal_note_id'].isna())
subset_3 = merged_df_full_gloss_to_marginalia[condition_3]

# Count of rows with None marginal_note_id_VLO41, None marginal_note_id_Bamberg, and non-None marginal_note_id
count_3 = subset_3.shape[0]

total_rows = merged_df_full_gloss_to_marginalia.shape[0]

# Calculate percentages
percentage_1 = (count_1 / total_rows) * 100
percentage_2 = (count_2 / total_rows) * 100
percentage_3 = (count_3 / total_rows) * 100


print(f"Rows with None marginal_note_id_VLO41 and non-None marginal_note_id_Bamberg: {count_1}")
print(f"Rows with None marginal_note_id_Bamberg and not None marginal_note_id: {count_2}")
print(f"Rows with None marginal_note_id_VLO41, and non-None marginal_note_id: {count_3}")

print(f"Percentage of rows with None marginal_note_id_VLO41 and non-None marginal_note_id_Bamberg: {percentage_1:.2f}%")
print(f"Percentage of rows with None marginal_note_id_Bamberg and not None marginal_note_id: {percentage_2:.2f}%")
print(f"Percentage of rows with None marginal_note_id_VLO41, and non-None marginal_note_id: {percentage_3:.2f}%")
# Out:
# Rows with None marginal_note_id_VLO41 and non-None marginal_note_id_Bamberg: 111
# Rows with None marginal_note_id_Bamberg and not None marginal_note_id: 80
# Rows with None marginal_note_id_VLO41, and non-None marginal_note_id: 113
# Percentage of rows with None marginal_note_id_VLO41 and non-None marginal_note_id_Bamberg: 22.33%
# Percentage of rows with None marginal_note_id_Bamberg and not None marginal_note_id: 16.10%
# Percentage of rows with None marginal_note_id_VLO41, and non-None marginal_note_id: 22.74%

# %%
import matplotlib.pyplot as plt

# Define the labels and percentages
labels = ['Bamberg to Lat7499', 'VLO41 to Bamberg', 'VLO41 to Lat7499']
percentages = [percentage_2, percentage_1, percentage_3]

# Create a figure
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the bar plot with custom colors
bar_colors = ['#85E7CB', '#34D0A2', '#00A781']
ax.bar(labels, percentages, color=bar_colors)
ax.set_xlabel('Categories')
ax.set_ylabel('Percentage')
ax.set_title('Percentage of increase of marginal notes on lemmas already bearing interlinear glosses')
ax.set_xticklabels(labels)
ax.set_ylim(0, max(percentages) + 10)

# Add value labels to the bars
for i, percentage in enumerate(percentages):
    ax.text(i, percentage, f'{percentage:.2f}%', ha='center', va='bottom', color='black')

# Customize the plot aesthetics
plt.grid(axis='y', linestyle='--', alpha=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Display and save the plot
plt.tight_layout()
plt.savefig('graphs/incremental_gloss_to_marge.png')
plt.show()
# Out:
# /var/folders/ps/09_p7rl14y11qx52mcmvrr_w0000gq/T/ipykernel_87005/709202595.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %% [markdown]
# ## The core gloss tradition passed down to every single mss with the same form and type no matter the divergencies though

# %%
# Filter the rows where the conditions are met
common_all = merged_df_full[
    (merged_df_full['gloss_type_VLO41'] == merged_df_full['gloss_type_Bamberg']) &
    (merged_df_full['gloss_type_Bamberg'] == merged_df_full['gloss_type']) &
    (merged_df_full['gloss_form_VLO41'] == merged_df_full['gloss_form_Bamberg']) &
    (merged_df_full['gloss_form_Bamberg'] == merged_df_full['gloss_form'])
]


# Select the desired columns
common_all = common_all[['lemma_id', 'gloss_type_VLO41', 'gloss_type_Bamberg', 'gloss_type',
                         'gloss_form_VLO41', 'gloss_form_Bamberg', 'gloss_form']]

# Merge with merged_df_Bamberg_Lat7499 to get 'lemma_Bamberg' and 'lemma_Lat7499'
common_all = common_all.merge(merged_df_full[['lemma_id', 'lemma_VLO41', 'gloss_VLO41', 'lemma_Bamberg', 'gloss_Bamberg', 'lemma', 'gloss']],
                              on='lemma_id', how='left')

# Save the result as a CSV file
common_all.to_csv('identical_glosses_csv/identical_glosses_allmss.csv', index=False)

# Display the new DataFrame
common_all
# Out:
#          lemma_id gloss_type_VLO41 gloss_type_Bamberg gloss_type  \
# 0    p447_l05_o06              S22                S22        S22
# 1    p447_l07_o01              S22                S22        S22
# 2    p447_l07_o03              S22                S22        S22
# 3    p447_l11_o06              S22                S22        S22
# 4    p447_l13_o03              S22                S22        S22
# ..            ...              ...                ...        ...
# 109  p463_l15_o03              S22                S22        S22
# 110  p463_l25_o09              S22                S22        S22
# 111  p466_l06_o03              S22                S22        S22
# 112  p466_l21_o09              S23                S23        S23
# 113  p470_l09_o07              S22                S22        S22
#
#     gloss_form_VLO41 gloss_form_Bamberg gloss_form lemma_VLO41  \
# 0                 F2                 F2         F2   auditorum
# 1                 F2                 F2         F2   desiderat
# 2                 F2                 F2         F2      recens
# 3                 F2                 F2         F2      romana
# 4                 F3                 F3         F3  instruitur
# ..               ...                ...        ...         ...
# 109               F2                 F2         F2    insignis
# 110               F2                 F2         F2      metior
# 111               F2                 F2         F2       rimor
# 112               F4                 F4         F4    paciscor
# 113               F2                 F2         F2      glisco
#
#                     gloss_VLO41 lemma_Bamberg            gloss_Bamberg  \
# 0               iđ discipulorũ    AVDITORVM              discipulorũ
# 1                         cupit     desider&                c̃cupiscat
# 2                     nouit(er)       recens                     nouum
# 3                          lat̃       romana                    latina
# 4    ordinatur /(et di)sponitur    instruit᷑   disponit᷑ ORDIN ͣ ͭ ͧ ͬ
# ..                          ...           ...                      ...
# 109                     nobilis     insignis                   nobilis
# 110                     mensuro        M&ior                    m̃suro
# 111                    ꝑscrutor        Rimor                 inuestigo
# 112                 pactũ facio     Paciscor               pacẽ facio
# 113                      cresco       Glisco                    cresco
#
#            lemma                  gloss
# 0     AVDITORṼ              discipuloꝵ
# 1     desideret              .s. audire
# 2        recens                   Nouũ
# 3        romana                ÷ latina
# 4     instruit᷑   ordinat᷑ et disponit᷑
# ..           ...                    ...
# 109  in̶asignis                 nobilis
# 110      metior               ÷ mensuro
# 111       Rimor                  inqͥro
# 112     pacisor             pacẽ fatio
# 113      Glisco                  cresco
#
# [114 rows x 13 columns]

# %% [markdown]
# ## Let's see if we can establish a similarity index.

# %%
# Manuscripts
manuscripts = ["VLO41", "Bamberg", "Lat14087", "Lat7499"]

# Dictionary to store the length of identical lemmas between each pair of manuscripts (intersections)
identical_lengths = {
    ('VLO41', 'Bamberg'): 238,
    ('VLO41', 'Lat7499'): 232,
    ('VLO41', 'Lat14087'): 32,
    ('Bamberg', 'Lat7499'): 514,
    ('Bamberg', 'Lat14087'): 48,
    ('Lat14087', 'Lat7499'): 46,
}

# Dictionary to store the length of shared lemmas between each pair of manuscripts (union)
shared_lengths = {
    ('VLO41', 'Bamberg'): 564,
    ('VLO41', 'Lat7499'): 644,
    ('VLO41', 'Lat14087'): 142,
    ('Bamberg', 'Lat7499'): 1103,
    ('Bamberg', 'Lat14087'): 165,
    ('Lat14087', 'Lat7499'): 168,
}

def calculate_jaccard_similarity(manuscripts, identical_lengths, shared_lengths):
    num_manuscripts = len(manuscripts)
    jaccard_matrix = np.zeros((num_manuscripts, num_manuscripts))
    
    for i in range(num_manuscripts):
        for j in range(i+1, num_manuscripts):
            manuscript1 = manuscripts[i]
            manuscript2 = manuscripts[j]
            intersection = identical_lengths.get((manuscript1, manuscript2), 0)
            union = shared_lengths.get((manuscript1, manuscript2), 0)
            jaccard_similarity = intersection / union
            jaccard_matrix[i, j] = jaccard_similarity
    
    # Copy the upper triangle to the lower triangle to make the matrix symmetric
    jaccard_matrix += jaccard_matrix.T
    
    # Create DataFrame for Jaccard matrix
    df_jaccard = pd.DataFrame(jaccard_matrix, columns=manuscripts, index=manuscripts)
    
    return df_jaccard

# Calculate Jaccard similarity
df_jaccard = calculate_jaccard_similarity(manuscripts, identical_lengths, shared_lengths)

# Print the Jaccard similarity DataFrame
df_jaccard
# Out:
#              VLO41   Bamberg  Lat14087   Lat7499
# VLO41     0.000000  0.421986  0.225352  0.360248
# Bamberg   0.421986  0.000000  0.290909  0.466002
# Lat14087  0.225352  0.290909  0.000000  0.273810
# Lat7499   0.360248  0.466002  0.273810  0.000000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Manuscripts
manuscripts = ["VLO41", "Bamberg", "Lat14087", "Lat7499"]

# Distance matrix
distance_matrix = np.array(df_jaccard)

# Create DataFrame for distance matrix
df_distance = pd.DataFrame(distance_matrix, columns=manuscripts, index=manuscripts)

df_distance = df_distance.round(2)  # Specify the desired decimal precision

# Create heatmap
sns.heatmap(df_distance, annot=True, cmap="YlGnBu")

# Add labels and title
plt.xlabel("Manuscripts")
plt.ylabel("Manuscripts")
plt.title("Pairwise Jaccard Distances")

plt.savefig('graphs/jaccard_similarity.png')


# Show the plot
plt.show()
